# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import lxml
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm

# %% [markdown]
# # Scrape data from IMDB

# %%
urls = ['https://www.imdb.com/search/title/?title_type=feature&ref_=adv_prv']

index = 51
for i in range(99):
    urls.append('https://www.imdb.com/search/title/?title_type=feature&start=%d&ref_=adv_nxt'
                % index)
    index += 50

# %%
movies = []

for url in tqdm(urls, position=0, leave=True):
    
    # Get data from url and parse it.
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml') # 'html' give same result
    
    # Scrape from wanted fields
    content = soup.find(id="main")
    movie_data = content.find_all("div", class_='lister-item mode-advanced')
    
    for i in range(len(movie_data)):

        # Header
        header = movie_data[i].find('h3')
        try:
            link = header.find('a').attrs['href']
            link = 'imdb.com' + link
        except:
            link = None    
        try:
            title = header.find('a').text
        except:
            title = None
        try:    
            year = header.find('span', class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','')
            try:
                year = int(year)
            except: # some has got 'II 2020'
                year = int(year.split(' ')[1])
        except:
            year = None

        # Info
        info = movie_data[i].find_all('p', class_='text-muted')[0]
        try:
            certificate = info.find('span', class_='certificate').text
        except:
            certificate = None
        try:
            runtime = int(info.find('span', class_='runtime').text.split(' ')[0])
        except:
            runtime = None
        try:
            genre = info.find('span', class_='genre').text.replace('\n','').strip()#.split(',')
        except:
            genre = None

        # Score
        score = movie_data[i].find('div', class_='ratings-bar')
        try:
            rating = float(score.find('strong').text)
        except:
            rating = None
        try:
            metascore = int(score.find('span', class_='metascore favorable').text.replace(' ',''))
        except:
            metascore = None

        # Story
        try:
            story = movie_data[i].find_all('p', class_='text-muted')[1].text.replace('\n','').strip()
        except:
            story = None

        # People
        people = movie_data[i].find('p', class_='').text

        if '|' in people: # movies
            try:
                director = people.split('|')[0].replace('\n','').strip().replace('Directors:','').replace('Director:','')
                #director = [name.strip() for name in director.split(',')]
            except:
                director = None
            try:
                cast = people.split('|')[1].replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        else: # series
            director = None
            try:
                cast = people.replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        # Store each in a dict
        movie_dict = {}
        movie_dict['link'] = link
        movie_dict['title'] = title
        movie_dict['year'] = year
        movie_dict['certificate'] = certificate
        movie_dict['runtime'] = runtime
        movie_dict['genre'] = genre
        movie_dict['rating'] = rating
        movie_dict['metascore'] = metascore
        movie_dict['story'] = story
        movie_dict['director'] = director
        movie_dict['cast'] = cast

        # Append the dict to a list
        movies.append(movie_dict)
# Out:
# 100%|██████████| 100/100 [02:39<00:00,  2.06s/it]

# %% [markdown]
# # Convert to DataFrame
# DataFrame converts ```year```, ```runtime```, and ```metascore``` which were ```int``` to ```float```. Further processings, include ```.dropna()``` and ```.astype()```, are required to convert them back.

# %%
# Convert to DataFrame and rearrange columns order
df = pd.DataFrame(movies, columns=['title','year','certificate','runtime','genre','rating','metascore','story','director','cast','link'])
df
# Out:
#                                                   title    year certificate  \
# 0                                            Uncut Gems  2019.0           R
# 1                                                 Tenet  2020.0        None
# 2                                     The Vast of Night  2019.0       PG-13
# 3                  Secret Society of Second-Born Royals  2020.0        None
# 4                                       The Wrong Missy  2020.0        None
# 5                                                 Joker  2019.0          18
# 6                       The Last Days of American Crime  2020.0        None
# 7                                              The Hunt  2020.0           R
# 8                                               365 dni  2020.0        None
# 9                                           Snowpiercer  2013.0           R
# 10                                         Gisaengchung  2019.0          15
# 11                                    The Invisible Man  2020.0          18
# 12                                           Knives Out  2019.0          15
# 13                     Once Upon a Time... in Hollywood  2019.0          18
# 14                                        The Gentlemen  2019.0          15
# 15                                           Just Mercy  2019.0       PG-13
# 16                                           Extraction  2020.0           R
# 17                                                 1917  2019.0           R
# 18                                                 Dune  2020.0        None
# 19                                    Avengers: Endgame  2019.0          13
# 20                                            Rocketman  2019.0          18
# 21                                                Becky  2020.0           R
# 22                                             The Help  2011.0       PG-13
# 23                                               Scoob!  2020.0          PG
# 24                                         Ready or Not  2019.0          18
# 25                                        The Lovebirds  2020.0           R
# 26                                             Clueless  1995.0       PG-13
# 27    The Lord of the Rings: The Fellowship of the Ring  2001.0       PG-13
# 28                                            Midsommar  2019.0          20
# 29                                          Jojo Rabbit  2019.0       PG-13
# ...                                                 ...     ...         ...
# 4970                                            Laggies  2014.0           R
# 4971                                      The Wanderers  1979.0        None
# 4972                                   Virgin Territory  2007.0           R
# 4973                                       Runaway Jury  2003.0       PG-13
# 4974                                     The Collection  2012.0           R
# 4975                                       I Walk Alone  1947.0        None
# 4976                                   Just Like Heaven  2005.0       PG-13
# 4977                                  Lord of the Flies  1963.0        None
# 4978                             Magic in the Moonlight  2014.0       PG-13
# 4979                                        Underground  1995.0        None
# 4980                                   Jeremiah Johnson  1972.0          GP
# 4981                              Judgment at Nuremberg  1961.0        None
# 4982                        Around the World in 80 Days  1956.0        None
# 4983                                Measure for Measure  2019.0        None
# 4984                             Naissance des pieuvres  2007.0        None
# 4985                                   Mulholland Falls  1996.0           R
# 4986                                 Yeh Saali Aashiqui  2019.0        None
# 4987                             Hannah and Her Sisters  1986.0        None
# 4988                                        Poltergeist  2015.0          13
# 4989                                Eight Legged Freaks  2002.0       PG-13
# 4990                                           Cook Off  2017.0        None
# 4991                             Swades: We, the People  2004.0        None
# 4992                                         Prom Night  1980.0        None
# 4993                                         Kill Chain  2019.0          18
# 4994                                     Johnny Be Good  1988.0        None
# 4995                                        Windtalkers  2002.0           R
# 4996               Police Academy 4: Citizens on Patrol  1987.0        None
# 4997                                         You Get Me  2017.0        None
# 4998                                         Dark Light  2019.0        None
# 4999                                    Far from Heaven  2002.0       PG-13
#
#       runtime                         genre  rating  metascore  \
# 0       135.0        Crime, Drama, Thriller     7.5       90.0
# 1         NaN      Action, Sci-Fi, Thriller     NaN        NaN
# 2        89.0        Drama, Mystery, Sci-Fi     6.7       84.0
# 3         NaN     Action, Adventure, Comedy     NaN        NaN
# 4        90.0               Comedy, Romance     5.7        NaN
# 5       122.0        Crime, Drama, Thriller     8.5        NaN
# 6       148.0       Action, Crime, Thriller     3.6        NaN
# 7        90.0      Action, Horror, Thriller     6.4        NaN
# 8       114.0                         Drama     3.7        NaN
# 9       126.0         Action, Drama, Sci-Fi     7.1       84.0
# 10      132.0       Comedy, Drama, Thriller     8.6       96.0
# 11      124.0       Horror, Mystery, Sci-Fi     7.1       72.0
# 12      130.0          Comedy, Crime, Drama     7.9       82.0
# 13      161.0                 Comedy, Drama     7.7       83.0
# 14      113.0         Action, Comedy, Crime     7.9        NaN
# 15      137.0       Biography, Crime, Drama     7.6       68.0
# 16      116.0       Action, Crime, Thriller     6.8        NaN
# 17      119.0                    Drama, War     8.3       78.0
# 18        NaN      Adventure, Drama, Sci-Fi     NaN        NaN
# 19      181.0      Action, Adventure, Drama     8.4       78.0
# 20      121.0       Biography, Drama, Music     7.3       69.0
# 21       93.0         Action, Drama, Horror     5.7        NaN
# 22      146.0                         Drama     8.1       62.0
# 23       93.0  Animation, Adventure, Comedy     5.8        NaN
# 24       95.0       Comedy, Horror, Mystery     6.8       64.0
# 25       86.0         Action, Comedy, Crime     6.0        NaN
# 26       97.0               Comedy, Romance     6.8       68.0
# 27      178.0      Action, Adventure, Drama     8.8       92.0
# 28      148.0        Drama, Horror, Mystery     7.1       72.0
# 29      108.0            Comedy, Drama, War     7.9        NaN
# ...       ...                           ...     ...        ...
# 4970     99.0        Comedy, Drama, Romance     6.4       63.0
# 4971    112.0                         Drama     7.4       64.0
# 4972     97.0    Adventure, Comedy, History     4.8        NaN
# 4973    127.0        Crime, Drama, Thriller     7.1       61.0
# 4974     82.0      Action, Adventure, Crime     6.1        NaN
# 4975     97.0       Crime, Drama, Film-Noir     7.0        NaN
# 4976     95.0        Comedy, Drama, Fantasy     6.7        NaN
# 4977     92.0    Adventure, Drama, Thriller     6.9       67.0
# 4978     97.0        Comedy, Drama, Romance     6.5        NaN
# 4979    170.0            Comedy, Drama, War     8.1        NaN
# 4980    108.0     Adventure, Drama, Western     7.6       75.0
# 4981    179.0                    Drama, War     8.2        NaN
# 4982    167.0     Adventure, Comedy, Family     6.8        NaN
# 4983    107.0                         Drama     5.7        NaN
# 4984     85.0                Drama, Romance     6.7       65.0
# 4985    107.0         Crime, Drama, Mystery     6.3        NaN
# 4986    137.0                      Thriller     7.9        NaN
# 4987    107.0                 Comedy, Drama     7.9       90.0
# 4988     93.0              Horror, Thriller     4.9        NaN
# 4989     99.0     Action, Adventure, Comedy     5.4        NaN
# 4990    101.0               Comedy, Romance     6.0        NaN
# 4991    210.0                         Drama     8.2        NaN
# 4992     92.0              Horror, Thriller     5.4        NaN
# 4993     91.0              Action, Thriller     5.0        NaN
# 4994     91.0                 Comedy, Sport     4.6        NaN
# 4995    134.0            Action, Drama, War     6.1        NaN
# 4996     88.0                 Comedy, Crime     5.0        NaN
# 4997     89.0         Crime, Drama, Romance     4.6        NaN
# 4998     90.0      Horror, Sci-Fi, Thriller     4.2        NaN
# 4999    107.0                         Drama     7.3       84.0
#
#                                                   story  \
# 0     With his debts mounting and angry collectors c...
# 1     Armed with only one word -- Tenet -- and fight...
# 2     In the twilight of the 1950s, on one fateful n...
# 3     It follows Sam's adventures at a top-secret tr...
# 4     Tim thinks he's invited the woman of his dream...
# 5     In Gotham City, mentally troubled comedian Art...
# 6     In the not-too-distant future, as a final resp...
# 7     Twelve strangers wake up in a clearing. They d...
# 8     Massimo is a member of the Sicilian Mafia fami...
# 9     In a future where a failed climate-change expe...
# 10    Greed and class discrimination threaten the ne...
# 11    When Cecilia's abusive ex takes his own life a...
# 12    A detective investigates the death of a patria...
# 13    A faded television actor and his stunt double ...
# 14    An American expat tries to sell off his highly...
# 15    World-renowned civil rights defense attorney B...
# 16    Tyler Rake, a fearless black market mercenary,...
# 17    April 6th, 1917. As a regiment assembles to wa...
# 18    Feature adaptation of Frank Herbert's science ...
# 19    After the devastating events of Avengers: Infi...
# 20    A musical fantasy about the fantastical human ...
# 21    A teenager's weekend at a lake house with her ...
# 22    An aspiring author during the civil rights mov...
# 23    Scooby and the gang face their most challengin...
# 24    A bride's wedding night takes a sinister turn ...
# 25    A couple (Issa Rae and Kumail Nanjiani) experi...
# 26    Shallow, rich and socially successful Cher is ...
# 27    A meek Hobbit from the Shire and eight compani...
# 28    A couple travels to Sweden to visit a rural ho...
# 29    A young boy in Hitler's army finds out his mot...
# ...                                                 ...
# 4970  In the throes of a quarter-life crisis, Megan ...
# 4971  The Wanderers is a teenage, Italian gang in Br...
# 4972  Young Florentines take refuge from the black p...
# 4973  A juror on the inside and a woman on the outsi...
# 4974  A man who escapes from the vicious grips of th...
# 4975  Frankie Madison leaves prison expecting a shar...
# 4976  A lonely landscape architect falls for the spi...
# 4977  Lost on an island, young survivors of a plane ...
# 4978  A romantic comedy about an Englishman brought ...
# 4979  A group of Serbian socialists prepares for the...
# 4980  A mountain man who wishes to live the life of ...
# 4981  In 1948, an American court in occupied Germany...
# 4982  A Victorian Englishman bets that with the new ...
# 4983  The lives of inhabitants of a housing commissi...
# 4984  After meeting at a local pool over their summe...
# 4985  In 1950's Los Angeles, a special crime squad o...
# 4986  While in college, Sahil and Mittee fall in lov...
# 4987  Between two Thanksgivings two years apart, Han...
# 4988  A family whose suburban home is haunted by evi...
# 4989  Venomous spiders get exposed to a noxious chem...
# 4990  Single mother Anesu's life is turned upside do...
# 4991  A successful Indian scientist returns to an In...
# 4992  At a high school senior prom, a masked killer ...
# 4993  Three strangers' lives are inevitably entangle...
# 4994  Johnny's the top high-school football player a...
# 4995  Two U.S. Marines in World War II are assigned ...
# 4996  The misfit Police Academy (1984) graduates now...
# 4997  A one night stand turns into a nightmare for a...
# 4998  A woman returns to her family home and discove...
# 4999  In 1950s Connecticut, a housewife faces a mari...
#
#                                   director  \
# 0                Benny Safdie, Josh Safdie
# 1                        Christopher Nolan
# 2                         Andrew Patterson
# 3                              Anna Mastro
# 4                            Tyler Spindel
# 5                            Todd Phillips
# 6                          Olivier Megaton
# 7                              Craig Zobel
# 8          Barbara Bialowas, Tomasz Mandes
# 9                             Bong Joon Ho
# 10                            Bong Joon Ho
# 11                          Leigh Whannell
# 12                            Rian Johnson
# 13                       Quentin Tarantino
# 14                             Guy Ritchie
# 15                   Destin Daniel Cretton
# 16                            Sam Hargrave
# 17                              Sam Mendes
# 18                        Denis Villeneuve
# 19                Anthony Russo, Joe Russo
# 20                         Dexter Fletcher
# 21           Jonathan Milott, Cary Murnion
# 22                             Tate Taylor
# 23                            Tony Cervone
# 24    Matt Bettinelli-Olpin, Tyler Gillett
# 25                       Michael Showalter
# 26                          Amy Heckerling
# 27                           Peter Jackson
# 28                               Ari Aster
# 29                           Taika Waititi
# ...                                    ...
# 4970                          Lynn Shelton
# 4971                        Philip Kaufman
# 4972                          David Leland
# 4973                           Gary Fleder
# 4974                        Marcus Dunstan
# 4975                          Byron Haskin
# 4976                           Mark Waters
# 4977                           Peter Brook
# 4978                           Woody Allen
# 4979                        Emir Kusturica
# 4980                        Sydney Pollack
# 4981                        Stanley Kramer
# 4982         Michael Anderson, John Farrow
# 4983                          Paul Ireland
# 4984                        Céline Sciamma
# 4985                          Lee Tamahori
# 4986                        Cherag Ruparel
# 4987                           Woody Allen
# 4988                             Gil Kenan
# 4989                        Ellory Elkayem
# 4990                       Tomas Brickhill
# 4991                    Ashutosh Gowariker
# 4992                            Paul Lynch
# 4993                            Ken Sanzel
# 4994                          Bud S. Smith
# 4995                              John Woo
# 4996                             Jim Drake
# 4997                       Brent Bonacorso
# 4998                      Padraig Reynolds
# 4999                           Todd Haynes
#
#                                                    cast  \
# 0     Adam Sandler, Julia Fox, Idina Menzel, Mesfin ...
# 1     John David Washington, Robert Pattinson, Eliza...
# 2     Sierra McCormick, Jake Horowitz, Gail Cronauer...
# 3     Elodie Yung, Skylar Astin, Greg Bryk, Julie Nolke
# 4     David Spade, Lauren Lapkus, Nick Swardson, Geo...
# 5     Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...
# 6     Neels Clasen, Edgar Ramírez, Tony Caprari, Kat...
# 7     Betty Gilpin, Hilary Swank, Ike Barinholtz, Wa...
# 8     Michele Morrone, Anna Maria Sieklucka, Bronisl...
# 9     Chris Evans, Jamie Bell, Tilda Swinton, Ed Harris
# 10    Kang-ho Song, Sun-kyun Lee, Yeo-jeong Jo, Woo-...
# 11    Elisabeth Moss, Oliver Jackson-Cohen, Harriet ...
# 12    Daniel Craig, Chris Evans, Ana de Armas, Jamie...
# 13    Leonardo DiCaprio, Brad Pitt, Margot Robbie, E...
# 14    Matthew McConaughey, Charlie Hunnam, Michelle ...
# 15    Michael B. Jordan, Jamie Foxx, Brie Larson, Ch...
# 16    Chris Hemsworth, Bryon Lerum, Ryder Lerum, Rud...
# 17    Dean-Charles Chapman, George MacKay, Daniel Ma...
# 18    Rebecca Ferguson, Timothée Chalamet, Zendaya, ...
# 19    Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 20    Taron Egerton, Jamie Bell, Richard Madden, Bry...
# 21    Lulu Wilson, Kevin James, Joel McHale, Robert ...
# 22    Emma Stone, Viola Davis, Octavia Spencer, Bryc...
# 23    Will Forte, Mark Wahlberg, Jason Isaacs, Gina ...
# 24    Samara Weaving, Adam Brody, Mark O'Brien, Henr...
# 25    Issa Rae, Kumail Nanjiani, Paul Sparks, Anna Camp
# 26    Alicia Silverstone, Stacey Dash, Brittany Murp...
# 27    Elijah Wood, Ian McKellen, Orlando Bloom, Sean...
# 28    Florence Pugh, Jack Reynor, Vilhelm Blomgren, ...
# 29    Roman Griffin Davis, Thomasin McKenzie, Scarle...
# ...                                                 ...
# 4970  Keira Knightley, Chloë Grace Moretz, Sam Rockw...
# 4971  Ken Wahl, Karen Allen, John Friedrich, Toni Kalem
# 4972  Hayden Christensen, Mischa Barton, Ryan Cartwr...
# 4973  John Cusack, Rachel Weisz, Gene Hackman, Dusti...
# 4974  Josh Stewart, Emma Fitzpatrick, Christopher Mc...
# 4975  Burt Lancaster, Lizabeth Scott, Kirk Douglas, ...
# 4976  Reese Witherspoon, Mark Ruffalo, Donal Logue, ...
# 4977  James Aubrey, Tom Chapin, Hugh Edwards, Roger ...
# 4978  Colin Firth, Emma Stone, Marcia Gay Harden, Ha...
# 4979  Predrag 'Miki' Manojlovic, Lazar Ristovski, Mi...
# 4980  Robert Redford, Will Geer, Delle Bolton, Josh ...
# 4981  Spencer Tracy, Burt Lancaster, Richard Widmark...
# 4982  David Niven, Cantinflas, Shirley MacLaine, Rob...
# 4983  Hugo Weaving, Daniel Henshall, Harrison Gilber...
# 4984  Pauline Acquart, Louise Blachère, Adèle Haenel...
# 4985  Nick Nolte, Melanie Griffith, Jennifer Connell...
# 4986  Vardhan Puri, Shivaleeka Oberoi, Ruslaan Mumta...
# 4987  Mia Farrow, Dianne Wiest, Michael Caine, Barba...
# 4988  Sam Rockwell, Rosemarie DeWitt, Kennedi Clemen...
# 4989  David Arquette, Kari Wuhrer, Scott Terra, Scar...
# 4990  Tendaiishe Chitima, Tomas Brickhill, Chirikure...
# 4991  Shah Rukh Khan, Gayatri Joshi, Kishori Ballal,...
# 4992  Leslie Nielsen, Jamie Lee Curtis, Casey Steven...
# 4993  Nicolas Cage, Enrico Colantoni, Ryan Kwanten, ...
# 4994  Anthony Michael Hall, Robert Downey Jr., Paul ...
# 4995  Nicolas Cage, Adam Beach, Peter Stormare, Noah...
# 4996  Steve Guttenberg, Bubba Smith, Michael Winslow...
# 4997  Bella Thorne, Halston Sage, Taylor John Smith,...
# 4998  Jessica Madsen, Opal Littleton, Ed Brody, Kris...
# 4999  Julianne Moore, Dennis Quaid, Dennis Haysbert,...
#
#                             link
# 0      imdb.com/title/tt5727208/
# 1      imdb.com/title/tt6723592/
# 2      imdb.com/title/tt6803046/
# 3     imdb.com/title/tt10324122/
# 4      imdb.com/title/tt9619798/
# 5      imdb.com/title/tt7286456/
# 6      imdb.com/title/tt1552211/
# 7      imdb.com/title/tt8244784/
# 8     imdb.com/title/tt10886166/
# 9      imdb.com/title/tt1706620/
# 10     imdb.com/title/tt6751668/
# 11     imdb.com/title/tt1051906/
# 12     imdb.com/title/tt8946378/
# 13     imdb.com/title/tt7131622/
# 14     imdb.com/title/tt8367814/
# 15     imdb.com/title/tt4916630/
# 16     imdb.com/title/tt8936646/
# 17     imdb.com/title/tt8579674/
# 18     imdb.com/title/tt1160419/
# 19     imdb.com/title/tt4154796/
# 20     imdb.com/title/tt2066051/
# 21    imdb.com/title/tt10314450/
# 22     imdb.com/title/tt1454029/
# 23     imdb.com/title/tt3152592/
# 24     imdb.com/title/tt7798634/
# 25     imdb.com/title/tt8851668/
# 26     imdb.com/title/tt0112697/
# 27     imdb.com/title/tt0120737/
# 28     imdb.com/title/tt8772262/
# 29     imdb.com/title/tt2584384/
# ...                          ...
# 4970   imdb.com/title/tt2034031/
# 4971   imdb.com/title/tt0080117/
# 4972   imdb.com/title/tt0437954/
# 4973   imdb.com/title/tt0313542/
# 4974   imdb.com/title/tt1748227/
# 4975   imdb.com/title/tt0039482/
# 4976   imdb.com/title/tt0425123/
# 4977   imdb.com/title/tt0057261/
# 4978   imdb.com/title/tt2870756/
# 4979   imdb.com/title/tt0114787/
# 4980   imdb.com/title/tt0068762/
# 4981   imdb.com/title/tt0055031/
# 4982   imdb.com/title/tt0048960/
# 4983   imdb.com/title/tt8846706/
# 4984   imdb.com/title/tt0869977/
# 4985   imdb.com/title/tt0117107/
# 4986  imdb.com/title/tt10443846/
# 4987   imdb.com/title/tt0091167/
# 4988   imdb.com/title/tt1029360/
# 4989   imdb.com/title/tt0271367/
# 4990   imdb.com/title/tt7981318/
# 4991   imdb.com/title/tt0367110/
# 4992   imdb.com/title/tt0081383/
# 4993   imdb.com/title/tt8535180/
# 4994   imdb.com/title/tt0095409/
# 4995   imdb.com/title/tt0245562/
# 4996   imdb.com/title/tt0093756/
# 4997   imdb.com/title/tt5539054/
# 4998   imdb.com/title/tt9135260/
# 4999   imdb.com/title/tt0297884/
#
# [5000 rows x 11 columns]

# %% [markdown]
# # Save to CSV File
# to load .csv into DataFrame, use ```pd.read_csv('file_path')```.

# %%
df.to_csv('imbd_movies.csv', index=False)

# %% [markdown]
# # Useful Links

# %% [markdown]
# credit: https://github.com/Reljod/Python-Data-Scraping-IMDb-Movie-site-using-BeautifulSoup-Series-1-
#
# resource: https://www.imdb.com/search/title/?title_type=feature,tv_series&view=advanced
