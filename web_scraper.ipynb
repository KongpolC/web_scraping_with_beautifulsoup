# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import lxml
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm

# %% [markdown]
# # Scrape data from IMDB

# %%
urls = ['https://www.imdb.com/search/title/?title_type=feature&ref_=adv_prv',
        'https://www.imdb.com/search/title/?title_type=feature&start=51&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=101&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=151&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=201&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=251&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=301&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=351&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=401&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=451&ref_=adv_nxt'
       ]

# %%
movies = []

for url in tqdm(urls, position=0, leave=True):
    
    # Get data from url and parse it.
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml') # 'html' give same result
    
    # Scrape from wanted fields
    content = soup.find(id="main")
    movie_data = content.find_all("div", class_='lister-item mode-advanced')
    
    for i in range(len(movie_data)):

        # Header
        header = movie_data[i].find('h3')
        try:
            link = header.find('a').attrs['href']
            link = 'imdb.com' + link
        except:
            link = None    
        try:
            title = header.find('a').text
        except:
            title = None
        try:    
            year = header.find('span', class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','')
            try:
                year = int(year)
            except: # some has got 'II 2020'
                year = int(year.split(' ')[1])
        except:
            year = None

        # Info
        info = movie_data[i].find_all('p', class_='text-muted')[0]
        try:
            certificate = info.find('span', class_='certificate').text
        except:
            certificate = None
        try:
            runtime = int(info.find('span', class_='runtime').text.split(' ')[0])
        except:
            runtime = None
        try:
            genre = info.find('span', class_='genre').text.replace(' ','').replace('\n','').split(',')
        except:
            genre = None

        # Score
        score = movie_data[i].find('div', class_='ratings-bar')
        try:
            rating = float(score.find('strong').text)
        except:
            rating = None
        try:
            metascore = int(score.find('span', class_='metascore favorable').text.replace(' ',''))
        except:
            metascore = None

        # Story
        try:
            story = movie_data[i].find_all('p', class_='text-muted')[1].text.replace('\n','').strip()
        except:
            story = None

        # People
        people = movie_data[i].find('p', class_='').text

        if '|' in people: # movies
            try:
                director = people.split('|')[0].replace('\n','').strip().replace('Directors:','').replace('Director:','')
                director = [name.strip() for name in director.split(',')]
            except:
                director = None
            try:
                cast = people.split('|')[1].replace('\n','').strip().replace('Stars:','')
                cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        else: # series
            director = None
            try:
                cast = people.replace('\n','').strip().replace('Stars:','')
                cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        # Store each in a dict
        movie_dict = {}
        movie_dict['link'] = link
        movie_dict['title'] = title
        movie_dict['year'] = year
        movie_dict['certificate'] = certificate
        movie_dict['runtime'] = runtime
        movie_dict['genre'] = genre
        movie_dict['rating'] = rating
        movie_dict['metascore'] = metascore
        movie_dict['story'] = story
        movie_dict['director'] = director
        movie_dict['cast'] = cast

        # Append the dict to a list
        movies.append(movie_dict)
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]

# %% [markdown]
# # Convert to DataFrame
# DataFrame converts ```year```, ```runtime```, and ```metascore``` which were ```int``` to ```float```. Further processings, include ```.dropna()``` and ```.astype()```, are required to convert them back.

# %%
# Convert to DataFrame and rearrange columns order
df = pd.DataFrame(movies, columns=['title','year','certificate','runtime','genre','rating','metascore','story','director','cast','link'])
df
# Out:
#                                                  title    year certificate  \
# 0                                           Uncut Gems  2019.0           R
# 1                                                Tenet  2020.0        None
# 2                                    The Vast of Night  2019.0       PG-13
# 3                 Secret Society of Second-Born Royals  2020.0        None
# 4                                      The Wrong Missy  2020.0        None
# 5                                                Joker  2019.0          18
# 6                      The Last Days of American Crime  2020.0        None
# 7                                             The Hunt  2020.0           R
# 8                                              365 dni  2020.0        None
# 9                                          Snowpiercer  2013.0           R
# 10                                        Gisaengchung  2019.0          15
# 11                                   The Invisible Man  2020.0          18
# 12                                          Knives Out  2019.0          15
# 13                    Once Upon a Time... in Hollywood  2019.0          18
# 14                                       The Gentlemen  2019.0          15
# 15                                          Just Mercy  2019.0       PG-13
# 16                                          Extraction  2020.0           R
# 17                                                1917  2019.0           R
# 18                                                Dune  2020.0        None
# 19                                   Avengers: Endgame  2019.0          13
# 20                                           Rocketman  2019.0          18
# 21                                               Becky  2020.0           R
# 22                                            The Help  2011.0       PG-13
# 23                                              Scoob!  2020.0          PG
# 24                                        Ready or Not  2019.0          18
# 25                                       The Lovebirds  2020.0           R
# 26                                            Clueless  1995.0       PG-13
# 27   The Lord of the Rings: The Fellowship of the Ring  2001.0       PG-13
# 28                                           Midsommar  2019.0          20
# 29                                         Jojo Rabbit  2019.0       PG-13
# ..                                                 ...     ...         ...
# 470                        Once Upon a Time in America  1984.0           R
# 471                                            Sicario  2015.0          15
# 472  Percy Jackson & the Olympians: The Lightning T...  2010.0          PG
# 473                        Mamma Mia! Here We Go Again  2018.0       PG-13
# 474                                     Mulholland Dr.  2001.0           R
# 475                                              Glass  2019.0          15
# 476                               Crazy, Stupid, Love.  2011.0       PG-13
# 477                       Kingsman: The Secret Service  2014.0          15
# 478                                     Twelve Monkeys  1995.0           R
# 479                                    Minority Report  2002.0       PG-13
# 480                       Malang - Unleash the Madness  2020.0        None
# 481                                    American Psycho  2000.0           R
# 482  The Chronicles of Narnia: The Lion, the Witch ...  2005.0          PG
# 483                                Motherless Brooklyn  2019.0           R
# 484                                            Spectre  2015.0          13
# 485                                     The Assignment  2016.0           R
# 486                                 The Shape of Water  2017.0          15
# 487                                Mission: Impossible  1996.0       PG-13
# 488     Star Wars: Episode V - The Empire Strikes Back  1980.0          PG
# 489                                           Free Guy  2020.0        None
# 490                                            Super 8  2011.0          13
# 491                      The Lost World: Jurassic Park  1997.0       PG-13
# 492                                    Die Another Day  2002.0          15
# 493                                        Point Break  1991.0           R
# 494                                       The Hangover  2009.0           R
# 495                                     Romeo + Juliet  1996.0       PG-13
# 496                                     Ocean's Eleven  2001.0       PG-13
# 497                                             Friday  1995.0           R
# 498                                  Fantastic Mr. Fox  2009.0          PG
# 499                                           Arkansas  2020.0           R
#
#      runtime                           genre  rating  metascore  \
# 0      135.0        [Crime, Drama, Thriller]     7.5       90.0
# 1        NaN      [Action, Sci-Fi, Thriller]     NaN        NaN
# 2       89.0        [Drama, Mystery, Sci-Fi]     6.7       84.0
# 3        NaN     [Action, Adventure, Comedy]     NaN        NaN
# 4       90.0               [Comedy, Romance]     5.7        NaN
# 5      122.0        [Crime, Drama, Thriller]     8.5        NaN
# 6      148.0       [Action, Crime, Thriller]     3.7        NaN
# 7       90.0      [Action, Horror, Thriller]     6.4        NaN
# 8      114.0                         [Drama]     3.8        NaN
# 9      126.0         [Action, Drama, Sci-Fi]     7.1       84.0
# 10     132.0       [Comedy, Drama, Thriller]     8.6       96.0
# 11     124.0       [Horror, Mystery, Sci-Fi]     7.1       72.0
# 12     130.0          [Comedy, Crime, Drama]     7.9       82.0
# 13     161.0                 [Comedy, Drama]     7.7       83.0
# 14     113.0         [Action, Comedy, Crime]     7.9        NaN
# 15     137.0       [Biography, Crime, Drama]     7.6       68.0
# 16     116.0       [Action, Crime, Thriller]     6.8        NaN
# 17     119.0                    [Drama, War]     8.3       78.0
# 18       NaN      [Adventure, Drama, Sci-Fi]     NaN        NaN
# 19     181.0      [Action, Adventure, Drama]     8.4       78.0
# 20     121.0       [Biography, Drama, Music]     7.3       69.0
# 21      93.0         [Action, Drama, Horror]     5.7        NaN
# 22     146.0                         [Drama]     8.1       62.0
# 23      93.0  [Animation, Adventure, Comedy]     5.8        NaN
# 24      95.0       [Comedy, Horror, Mystery]     6.8       64.0
# 25      86.0         [Action, Comedy, Crime]     6.0        NaN
# 26      97.0               [Comedy, Romance]     6.8       68.0
# 27     178.0      [Action, Adventure, Drama]     8.8       92.0
# 28     148.0        [Drama, Horror, Mystery]     7.1       72.0
# 29     108.0            [Comedy, Drama, War]     7.9        NaN
# ..       ...                             ...     ...        ...
# 470    229.0                  [Crime, Drama]     8.4        NaN
# 471    121.0          [Action, Crime, Drama]     7.6       82.0
# 472    118.0    [Adventure, Family, Fantasy]     5.9        NaN
# 473    114.0      [Comedy, Musical, Romance]     6.7        NaN
# 474    147.0      [Drama, Mystery, Thriller]     8.0       85.0
# 475    129.0       [Drama, Sci-Fi, Thriller]     6.7        NaN
# 476    118.0        [Comedy, Drama, Romance]     7.4       68.0
# 477    129.0     [Action, Adventure, Comedy]     7.7        NaN
# 478    129.0     [Mystery, Sci-Fi, Thriller]     8.0       74.0
# 479    145.0        [Action, Crime, Mystery]     7.6       80.0
# 480    135.0          [Action, Crime, Drama]     6.5        NaN
# 481    101.0          [Comedy, Crime, Drama]     7.6       64.0
# 482    143.0    [Adventure, Family, Fantasy]     6.9       75.0
# 483    144.0         [Crime, Drama, Mystery]     6.8        NaN
# 484    148.0   [Action, Adventure, Thriller]     6.8        NaN
# 485     95.0       [Action, Crime, Thriller]     4.6        NaN
# 486    123.0     [Adventure, Drama, Fantasy]     7.3       87.0
# 487    110.0   [Action, Adventure, Thriller]     7.1        NaN
# 488    124.0    [Action, Adventure, Fantasy]     8.7       82.0
# 489      NaN     [Action, Adventure, Comedy]     NaN        NaN
# 490    112.0     [Mystery, Sci-Fi, Thriller]     7.0       72.0
# 491    129.0     [Action, Adventure, Sci-Fi]     6.6        NaN
# 492    133.0   [Action, Adventure, Thriller]     6.1        NaN
# 493    122.0       [Action, Crime, Thriller]     7.3        NaN
# 494    100.0                        [Comedy]     7.7       73.0
# 495    120.0                [Drama, Romance]     6.7        NaN
# 496    116.0               [Crime, Thriller]     7.7       74.0
# 497     91.0                 [Comedy, Drama]     7.3        NaN
# 498     87.0  [Animation, Adventure, Comedy]     7.9       83.0
# 499    117.0        [Crime, Drama, Thriller]     5.9        NaN
#
#                                                  story  \
# 0    With his debts mounting and angry collectors c...
# 1    Armed with only one word -- Tenet -- and fight...
# 2    In the twilight of the 1950s, on one fateful n...
# 3    It follows Sam's adventures at a top-secret tr...
# 4    Tim thinks he's invited the woman of his dream...
# 5    In Gotham City, mentally troubled comedian Art...
# 6    In the not-too-distant future, as a final resp...
# 7    Twelve strangers wake up in a clearing. They d...
# 8    Massimo is a member of the Sicilian Mafia fami...
# 9    In a future where a failed climate-change expe...
# 10   Greed and class discrimination threaten the ne...
# 11   When Cecilia's abusive ex takes his own life a...
# 12   A detective investigates the death of a patria...
# 13   A faded television actor and his stunt double ...
# 14   An American expat tries to sell off his highly...
# 15   World-renowned civil rights defense attorney B...
# 16   Tyler Rake, a fearless black market mercenary,...
# 17   April 6th, 1917. As a regiment assembles to wa...
# 18   Feature adaptation of Frank Herbert's science ...
# 19   After the devastating events of Avengers: Infi...
# 20   A musical fantasy about the fantastical human ...
# 21   A teenager's weekend at a lake house with her ...
# 22   An aspiring author during the civil rights mov...
# 23   Scooby and the gang face their most challengin...
# 24   A bride's wedding night takes a sinister turn ...
# 25   A couple (Issa Rae and Kumail Nanjiani) experi...
# 26   Shallow, rich and socially successful Cher is ...
# 27   A meek Hobbit from the Shire and eight compani...
# 28   A couple travels to Sweden to visit a rural ho...
# 29   A young boy in Hitler's army finds out his mot...
# ..                                                 ...
# 470  A former Prohibition-era Jewish gangster retur...
# 471  An idealistic FBI agent is enlisted by a gover...
# 472  A teenager discovers he's the descendant of a ...
# 473  Five years after the events of Mamma Mia! (200...
# 474  After a car wreck on the winding Mulholland Dr...
# 475  Security guard David Dunn uses his supernatura...
# 476  A middle-aged husband's life changes dramatica...
# 477  A spy organisation recruits a promising street...
# 478  In a future world devastated by disease, a con...
# 479  In a future where a special police unit is abl...
# 480  Advait visits Goa where he meets Sara, a free-...
# 481  A wealthy New York City investment banking exe...
# 482  Four kids travel through a wardrobe to the lan...
# 483  In 1950s New York, a lonely private detective ...
# 484  A cryptic message from James Bond's past sends...
# 485  After waking up and discovering that he has un...
# 486  At a top secret research facility in the 1960s...
# 487  An American agent, under false suspicion of di...
# 488  After the Rebels are brutally overpowered by t...
# 489  A bank teller discovers that he's actually an ...
# 490  During the summer of 1979, a group of friends ...
# 491  A research team is sent to the Jurassic Park S...
# 492  James Bond is sent to investigate the connecti...
# 493  An F.B.I. Agent goes undercover to catch a gan...
# 494  Three buddies wake up from a bachelor party in...
# 495  Shakespeare's famous play is updated to the hi...
# 496  Danny Ocean and his ten accomplices plan to ro...
# 497  Two homies, Smokey and Craig Jones, smoke a do...
# 498  An urbane fox cannot resist returning to his f...
# 499  Kyle and Swin live by the orders of an Arkansa...
#
#                                    director  \
# 0               [Benny Safdie, Josh Safdie]
# 1                       [Christopher Nolan]
# 2                        [Andrew Patterson]
# 3                             [Anna Mastro]
# 4                           [Tyler Spindel]
# 5                           [Todd Phillips]
# 6                         [Olivier Megaton]
# 7                             [Craig Zobel]
# 8         [Barbara Bialowas, Tomasz Mandes]
# 9                            [Bong Joon Ho]
# 10                           [Bong Joon Ho]
# 11                         [Leigh Whannell]
# 12                           [Rian Johnson]
# 13                      [Quentin Tarantino]
# 14                            [Guy Ritchie]
# 15                  [Destin Daniel Cretton]
# 16                           [Sam Hargrave]
# 17                             [Sam Mendes]
# 18                       [Denis Villeneuve]
# 19               [Anthony Russo, Joe Russo]
# 20                        [Dexter Fletcher]
# 21          [Jonathan Milott, Cary Murnion]
# 22                            [Tate Taylor]
# 23                           [Tony Cervone]
# 24   [Matt Bettinelli-Olpin, Tyler Gillett]
# 25                      [Michael Showalter]
# 26                         [Amy Heckerling]
# 27                          [Peter Jackson]
# 28                              [Ari Aster]
# 29                          [Taika Waititi]
# ..                                      ...
# 470                          [Sergio Leone]
# 471                      [Denis Villeneuve]
# 472                        [Chris Columbus]
# 473                             [Ol Parker]
# 474                           [David Lynch]
# 475                    [M. Night Shyamalan]
# 476             [Glenn Ficarra, John Requa]
# 477                        [Matthew Vaughn]
# 478                         [Terry Gilliam]
# 479                      [Steven Spielberg]
# 480                            [Mohit Suri]
# 481                           [Mary Harron]
# 482                        [Andrew Adamson]
# 483                         [Edward Norton]
# 484                            [Sam Mendes]
# 485                           [Walter Hill]
# 486                    [Guillermo del Toro]
# 487                        [Brian De Palma]
# 488                        [Irvin Kershner]
# 489                            [Shawn Levy]
# 490                           [J.J. Abrams]
# 491                      [Steven Spielberg]
# 492                          [Lee Tamahori]
# 493                       [Kathryn Bigelow]
# 494                         [Todd Phillips]
# 495                          [Baz Luhrmann]
# 496                     [Steven Soderbergh]
# 497                          [F. Gary Gray]
# 498                          [Wes Anderson]
# 499                            [Clark Duke]
#
#                                                   cast  \
# 0    [Adam Sandler, Julia Fox, Idina Menzel, Mesfin...
# 1    [John David Washington, Robert Pattinson, Eliz...
# 2    [Sierra McCormick, Jake Horowitz, Gail Cronaue...
# 3    [Elodie Yung, Olivia Deeble, Peyton Elizabeth ...
# 4    [David Spade, Lauren Lapkus, Nick Swardson, Ge...
# 5    [Joaquin Phoenix, Robert De Niro, Zazie Beetz,...
# 6    [Neels Clasen, Edgar Ramírez, Tony Caprari, Ka...
# 7    [Betty Gilpin, Hilary Swank, Ike Barinholtz, W...
# 8    [Michele Morrone, Anna Maria Sieklucka, Bronis...
# 9    [Chris Evans, Jamie Bell, Tilda Swinton, Ed Ha...
# 10   [Kang-ho Song, Sun-kyun Lee, Yeo-jeong Jo, Woo...
# 11   [Elisabeth Moss, Oliver Jackson-Cohen, Harriet...
# 12   [Daniel Craig, Chris Evans, Ana de Armas, Jami...
# 13   [Leonardo DiCaprio, Brad Pitt, Margot Robbie, ...
# 14   [Matthew McConaughey, Charlie Hunnam, Michelle...
# 15   [Michael B. Jordan, Jamie Foxx, Brie Larson, C...
# 16   [Chris Hemsworth, Bryon Lerum, Ryder Lerum, Ru...
# 17   [Dean-Charles Chapman, George MacKay, Daniel M...
# 18   [Rebecca Ferguson, Timothée Chalamet, Zendaya,...
# 19   [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# 20   [Taron Egerton, Jamie Bell, Richard Madden, Br...
# 21   [Lulu Wilson, Kevin James, Joel McHale, Robert...
# 22   [Emma Stone, Viola Davis, Octavia Spencer, Bry...
# 23   [Will Forte, Mark Wahlberg, Jason Isaacs, Gina...
# 24   [Samara Weaving, Adam Brody, Mark O'Brien, Hen...
# 25   [Issa Rae, Kumail Nanjiani, Paul Sparks, Anna ...
# 26   [Alicia Silverstone, Stacey Dash, Brittany Mur...
# 27   [Elijah Wood, Ian McKellen, Orlando Bloom, Sea...
# 28   [Florence Pugh, Jack Reynor, Vilhelm Blomgren,...
# 29   [Roman Griffin Davis, Thomasin McKenzie, Scarl...
# ..                                                 ...
# 470  [Robert De Niro, James Woods, Elizabeth McGove...
# 471  [Emily Blunt, Josh Brolin, Benicio Del Toro, J...
# 472  [Logan Lerman, Kevin McKidd, Steve Coogan, Bra...
# 473  [Lily James, Amanda Seyfried, Meryl Streep, Cher]
# 474  [Naomi Watts, Laura Harring, Justin Theroux, J...
# 475  [James McAvoy, Bruce Willis, Samuel L. Jackson...
# 476  [Steve Carell, Ryan Gosling, Julianne Moore, E...
# 477  [Colin Firth, Taron Egerton, Samuel L. Jackson...
# 478  [Bruce Willis, Madeleine Stowe, Brad Pitt, Jos...
# 479  [Tom Cruise, Colin Farrell, Samantha Morton, M...
# 480  [Aditya Roy Kapoor, Anil Kapoor, Disha Patani,...
# 481  [Christian Bale, Justin Theroux, Josh Lucas, B...
# 482  [Tilda Swinton, Georgie Henley, William Mosele...
# 483  [Edward Norton, Gugu Mbatha-Raw, Alec Baldwin,...
# 484  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 485  [Michelle Rodriguez, Tony Shalhoub, Anthony La...
# 486  [Sally Hawkins, Octavia Spencer, Michael Shann...
# 487  [Tom Cruise, Jon Voight, Emmanuelle Béart, Hen...
# 488  [Mark Hamill, Harrison Ford, Carrie Fisher, Bi...
# 489  [Jodie Comer, Taika Waititi, Ryan Reynolds, Jo...
# 490  [Elle Fanning, AJ Michalka, Kyle Chandler, Joe...
# 491  [Jeff Goldblum, Julianne Moore, Pete Postlethw...
# 492  [Pierce Brosnan, Halle Berry, Rosamund Pike, T...
# 493  [Patrick Swayze, Keanu Reeves, Gary Busey, Lor...
# 494  [Zach Galifianakis, Bradley Cooper, Justin Bar...
# 495  [Leonardo DiCaprio, Claire Danes, John Leguiza...
# 496  [George Clooney, Brad Pitt, Julia Roberts, Mat...
# 497  [Ice Cube, Chris Tucker, Nia Long, Tommy 'Tiny...
# 498  [George Clooney, Meryl Streep, Bill Murray, Ja...
# 499  [Liam Hemsworth, Vince Vaughn, Clark Duke, Joh...
#
#                            link
# 0     imdb.com/title/tt5727208/
# 1     imdb.com/title/tt6723592/
# 2     imdb.com/title/tt6803046/
# 3    imdb.com/title/tt10324122/
# 4     imdb.com/title/tt9619798/
# 5     imdb.com/title/tt7286456/
# 6     imdb.com/title/tt1552211/
# 7     imdb.com/title/tt8244784/
# 8    imdb.com/title/tt10886166/
# 9     imdb.com/title/tt1706620/
# 10    imdb.com/title/tt6751668/
# 11    imdb.com/title/tt1051906/
# 12    imdb.com/title/tt8946378/
# 13    imdb.com/title/tt7131622/
# 14    imdb.com/title/tt8367814/
# 15    imdb.com/title/tt4916630/
# 16    imdb.com/title/tt8936646/
# 17    imdb.com/title/tt8579674/
# 18    imdb.com/title/tt1160419/
# 19    imdb.com/title/tt4154796/
# 20    imdb.com/title/tt2066051/
# 21   imdb.com/title/tt10314450/
# 22    imdb.com/title/tt1454029/
# 23    imdb.com/title/tt3152592/
# 24    imdb.com/title/tt7798634/
# 25    imdb.com/title/tt8851668/
# 26    imdb.com/title/tt0112697/
# 27    imdb.com/title/tt0120737/
# 28    imdb.com/title/tt8772262/
# 29    imdb.com/title/tt2584384/
# ..                          ...
# 470   imdb.com/title/tt0087843/
# 471   imdb.com/title/tt3397884/
# 472   imdb.com/title/tt0814255/
# 473   imdb.com/title/tt6911608/
# 474   imdb.com/title/tt0166924/
# 475   imdb.com/title/tt6823368/
# 476   imdb.com/title/tt1570728/
# 477   imdb.com/title/tt2802144/
# 478   imdb.com/title/tt0114746/
# 479   imdb.com/title/tt0181689/
# 480   imdb.com/title/tt9877170/
# 481   imdb.com/title/tt0144084/
# 482   imdb.com/title/tt0363771/
# 483   imdb.com/title/tt0385887/
# 484   imdb.com/title/tt2379713/
# 485   imdb.com/title/tt5034474/
# 486   imdb.com/title/tt5580390/
# 487   imdb.com/title/tt0117060/
# 488   imdb.com/title/tt0080684/
# 489   imdb.com/title/tt6264654/
# 490   imdb.com/title/tt1650062/
# 491   imdb.com/title/tt0119567/
# 492   imdb.com/title/tt0246460/
# 493   imdb.com/title/tt0102685/
# 494   imdb.com/title/tt1119646/
# 495   imdb.com/title/tt0117509/
# 496   imdb.com/title/tt0240772/
# 497   imdb.com/title/tt0113118/
# 498   imdb.com/title/tt0432283/
# 499   imdb.com/title/tt9139586/
#
# [500 rows x 11 columns]

# %% [markdown]
# # Save to CSV File
# to load .csv into DataFrame, use ```pd.read_csv('file_path')```.

# %%
df.to_csv('imbd_movies.csv', index=False)

# %% [markdown]
# # Useful Links

# %% [markdown]
# credit: https://github.com/Reljod/Python-Data-Scraping-IMDb-Movie-site-using-BeautifulSoup-Series-1-
#
# resource: https://www.imdb.com/search/title/?title_type=feature,tv_series&view=advanced
