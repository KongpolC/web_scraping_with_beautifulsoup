# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import lxml
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm

# %% [markdown]
# # Scrape data from IMDB

# %%
urls = ['https://www.imdb.com/search/title/?title_type=feature&ref_=adv_prv',
        'https://www.imdb.com/search/title/?title_type=feature&start=51&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=101&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=151&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=201&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=251&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=301&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=351&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=401&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=451&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=501&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=551&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=601&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=651&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=701&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=751&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=801&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=851&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=901&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=951&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1001&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1051&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1101&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1151&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1201&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1251&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1301&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1351&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1401&ref_=adv_nxt',
        'https://www.imdb.com/search/title/?title_type=feature&start=1451&ref_=adv_nxt',
       ]

# %%
movies = []

for url in tqdm(urls, position=0, leave=True):
    
    # Get data from url and parse it.
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml') # 'html' give same result
    
    # Scrape from wanted fields
    content = soup.find(id="main")
    movie_data = content.find_all("div", class_='lister-item mode-advanced')
    
    for i in range(len(movie_data)):

        # Header
        header = movie_data[i].find('h3')
        try:
            link = header.find('a').attrs['href']
            link = 'imdb.com' + link
        except:
            link = None    
        try:
            title = header.find('a').text
        except:
            title = None
        try:    
            year = header.find('span', class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','')
            try:
                year = int(year)
            except: # some has got 'II 2020'
                year = int(year.split(' ')[1])
        except:
            year = None

        # Info
        info = movie_data[i].find_all('p', class_='text-muted')[0]
        try:
            certificate = info.find('span', class_='certificate').text
        except:
            certificate = None
        try:
            runtime = int(info.find('span', class_='runtime').text.split(' ')[0])
        except:
            runtime = None
        try:
            genre = info.find('span', class_='genre').text.replace('\n','').strip()#.split(',')
        except:
            genre = None

        # Score
        score = movie_data[i].find('div', class_='ratings-bar')
        try:
            rating = float(score.find('strong').text)
        except:
            rating = None
        try:
            metascore = int(score.find('span', class_='metascore favorable').text.replace(' ',''))
        except:
            metascore = None

        # Story
        try:
            story = movie_data[i].find_all('p', class_='text-muted')[1].text.replace('\n','').strip()
        except:
            story = None

        # People
        people = movie_data[i].find('p', class_='').text

        if '|' in people: # movies
            try:
                director = people.split('|')[0].replace('\n','').strip().replace('Directors:','').replace('Director:','')
                #director = [name.strip() for name in director.split(',')]
            except:
                director = None
            try:
                cast = people.split('|')[1].replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        else: # series
            director = None
            try:
                cast = people.replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        # Store each in a dict
        movie_dict = {}
        movie_dict['link'] = link
        movie_dict['title'] = title
        movie_dict['year'] = year
        movie_dict['certificate'] = certificate
        movie_dict['runtime'] = runtime
        movie_dict['genre'] = genre
        movie_dict['rating'] = rating
        movie_dict['metascore'] = metascore
        movie_dict['story'] = story
        movie_dict['director'] = director
        movie_dict['cast'] = cast

        # Append the dict to a list
        movies.append(movie_dict)
# Out:
# 100%|██████████| 30/30 [00:53<00:00,  1.66s/it]

# %% [markdown]
# # Convert to DataFrame
# DataFrame converts ```year```, ```runtime```, and ```metascore``` which were ```int``` to ```float```. Further processings, include ```.dropna()``` and ```.astype()```, are required to convert them back.

# %%
# Convert to DataFrame and rearrange columns order
df = pd.DataFrame(movies, columns=['title','year','certificate','runtime','genre','rating','metascore','story','director','cast','link'])
df
# Out:
#                                                   title    year certificate  \
# 0                                            Uncut Gems  2019.0           R
# 1                                                 Tenet  2020.0        None
# 2                                     The Vast of Night  2019.0       PG-13
# 3                  Secret Society of Second-Born Royals  2020.0        None
# 4                                       The Wrong Missy  2020.0        None
# 5                                                 Joker  2019.0          18
# 6                       The Last Days of American Crime  2020.0        None
# 7                                              The Hunt  2020.0           R
# 8                                               365 dni  2020.0        None
# 9                                           Snowpiercer  2013.0           R
# 10                                         Gisaengchung  2019.0          15
# 11                                    The Invisible Man  2020.0          18
# 12                                           Knives Out  2019.0          15
# 13                     Once Upon a Time... in Hollywood  2019.0          18
# 14                                        The Gentlemen  2019.0          15
# 15                                           Just Mercy  2019.0       PG-13
# 16                                           Extraction  2020.0           R
# 17                                                 1917  2019.0           R
# 18                                                 Dune  2020.0        None
# 19                                    Avengers: Endgame  2019.0          13
# 20                                            Rocketman  2019.0          18
# 21                                                Becky  2020.0           R
# 22                                             The Help  2011.0       PG-13
# 23                                               Scoob!  2020.0          PG
# 24                                         Ready or Not  2019.0          18
# 25                                        The Lovebirds  2020.0           R
# 26                                             Clueless  1995.0       PG-13
# 27    The Lord of the Rings: The Fellowship of the Ring  2001.0       PG-13
# 28                                            Midsommar  2019.0          20
# 29                                          Jojo Rabbit  2019.0       PG-13
# ...                                                 ...     ...         ...
# 1470                                   Captain Phillips  2013.0          15
# 1471                                    Rosemary's Baby  1968.0        None
# 1472                                     Bachelor Party  1984.0        None
# 1473                                           The Mist  2007.0           R
# 1474                                            Bacurau  2019.0        None
# 1475                                            Gattaca  1997.0       PG-13
# 1476                                  The Moon-Spinners  1964.0        None
# 1477                    I Know What You Did Last Summer  1997.0           R
# 1478                          The Passion of the Christ  2004.0           R
# 1479                              House of 1000 Corpses  2003.0           R
# 1480                            The Secret Life of Pets  2016.0           G
# 1481                                        Source Code  2011.0       PG-13
# 1482                                        The Founder  2016.0       PG-13
# 1483                                                Spy  2015.0          15
# 1484                                       The Warriors  1979.0           R
# 1485                                      Inherent Vice  2014.0           R
# 1486                                     Men in Black 3  2012.0       PG-13
# 1487                                 Frankie and Johnny  1966.0        None
# 1488                                            Don Jon  2013.0           R
# 1489                                      The Foreigner  2017.0          15
# 1490                                         The Others  2001.0       PG-13
# 1491                                              Glory  1989.0        None
# 1492                                      Hunter Killer  2018.0          15
# 1493                                   The Elephant Man  1980.0        None
# 1494                                       Hotel Mumbai  2018.0           R
# 1495                                         Barbarella  1968.0        None
# 1496                                  Beverly Hills Cop  1984.0        None
# 1497                                         Eraserhead  1977.0        None
# 1498                             The Hitman's Bodyguard  2017.0          15
# 1499                                 Love & Other Drugs  2010.0           R
#
#       runtime                         genre  rating  metascore  \
# 0       135.0        Crime, Drama, Thriller     7.5       90.0
# 1         NaN      Action, Sci-Fi, Thriller     NaN        NaN
# 2        89.0        Drama, Mystery, Sci-Fi     6.7       84.0
# 3         NaN     Action, Adventure, Comedy     NaN        NaN
# 4        90.0               Comedy, Romance     5.7        NaN
# 5       122.0        Crime, Drama, Thriller     8.5        NaN
# 6       148.0       Action, Crime, Thriller     3.6        NaN
# 7        90.0      Action, Horror, Thriller     6.4        NaN
# 8       114.0                         Drama     3.7        NaN
# 9       126.0         Action, Drama, Sci-Fi     7.1       84.0
# 10      132.0       Comedy, Drama, Thriller     8.6       96.0
# 11      124.0       Horror, Mystery, Sci-Fi     7.1       72.0
# 12      130.0          Comedy, Crime, Drama     7.9       82.0
# 13      161.0                 Comedy, Drama     7.7       83.0
# 14      113.0         Action, Comedy, Crime     7.9        NaN
# 15      137.0       Biography, Crime, Drama     7.6       68.0
# 16      116.0       Action, Crime, Thriller     6.8        NaN
# 17      119.0                    Drama, War     8.3       78.0
# 18        NaN      Adventure, Drama, Sci-Fi     NaN        NaN
# 19      181.0      Action, Adventure, Drama     8.4       78.0
# 20      121.0       Biography, Drama, Music     7.3       69.0
# 21       93.0         Action, Drama, Horror     5.7        NaN
# 22      146.0                         Drama     8.1       62.0
# 23       93.0  Animation, Adventure, Comedy     5.8        NaN
# 24       95.0       Comedy, Horror, Mystery     6.8       64.0
# 25       86.0         Action, Comedy, Crime     6.0        NaN
# 26       97.0               Comedy, Romance     6.8       68.0
# 27      178.0      Action, Adventure, Drama     8.8       92.0
# 28      148.0        Drama, Horror, Mystery     7.1       72.0
# 29      108.0            Comedy, Drama, War     7.9        NaN
# ...       ...                           ...     ...        ...
# 1470    134.0       Biography, Crime, Drama     7.8       82.0
# 1471    137.0                 Drama, Horror     8.0       96.0
# 1472    105.0                        Comedy     6.3        NaN
# 1473    126.0                Horror, Sci-Fi     7.1        NaN
# 1474    131.0    Adventure, Mystery, Sci-Fi     7.6       82.0
# 1475    106.0       Drama, Sci-Fi, Thriller     7.8       64.0
# 1476    118.0      Family, Mystery, Romance     6.7        NaN
# 1477    101.0               Horror, Mystery     5.7        NaN
# 1478    127.0                         Drama     7.2        NaN
# 1479     89.0                        Horror     6.1        NaN
# 1480     87.0  Animation, Adventure, Comedy     6.5       61.0
# 1481     93.0        Action, Drama, Mystery     7.5       74.0
# 1482    115.0              Biography, Drama     7.2       66.0
# 1483    120.0         Action, Comedy, Crime     7.0       75.0
# 1484     92.0       Action, Crime, Thriller     7.6       65.0
# 1485    148.0          Comedy, Crime, Drama     6.7       81.0
# 1486    106.0     Action, Adventure, Comedy     6.8        NaN
# 1487     87.0      Comedy, Musical, Romance     5.7        NaN
# 1488     90.0        Comedy, Drama, Romance     6.5       66.0
# 1489    113.0              Action, Thriller     7.0        NaN
# 1490    101.0     Horror, Mystery, Thriller     7.6       74.0
# 1491    122.0     Biography, Drama, History     7.8       78.0
# 1492    122.0   Action, Adventure, Thriller     6.6        NaN
# 1493    124.0              Biography, Drama     8.1       78.0
# 1494    123.0        Action, Drama, History     7.6       62.0
# 1495     98.0    Adventure, Comedy, Fantasy     5.9        NaN
# 1496    105.0         Action, Comedy, Crime     7.3       66.0
# 1497     89.0                        Horror     7.4       87.0
# 1498    118.0         Action, Comedy, Crime     6.9        NaN
# 1499    112.0        Comedy, Drama, Romance     6.7        NaN
#
#                                                   story  \
# 0     With his debts mounting and angry collectors c...
# 1     Armed with only one word -- Tenet -- and fight...
# 2     In the twilight of the 1950s, on one fateful n...
# 3     It follows Sam's adventures at a top-secret tr...
# 4     Tim thinks he's invited the woman of his dream...
# 5     In Gotham City, mentally troubled comedian Art...
# 6     In the not-too-distant future, as a final resp...
# 7     Twelve strangers wake up in a clearing. They d...
# 8     Massimo is a member of the Sicilian Mafia fami...
# 9     In a future where a failed climate-change expe...
# 10    Greed and class discrimination threaten the ne...
# 11    When Cecilia's abusive ex takes his own life a...
# 12    A detective investigates the death of a patria...
# 13    A faded television actor and his stunt double ...
# 14    An American expat tries to sell off his highly...
# 15    World-renowned civil rights defense attorney B...
# 16    Tyler Rake, a fearless black market mercenary,...
# 17    April 6th, 1917. As a regiment assembles to wa...
# 18    Feature adaptation of Frank Herbert's science ...
# 19    After the devastating events of Avengers: Infi...
# 20    A musical fantasy about the fantastical human ...
# 21    A teenager's weekend at a lake house with her ...
# 22    An aspiring author during the civil rights mov...
# 23    Scooby and the gang face their most challengin...
# 24    A bride's wedding night takes a sinister turn ...
# 25    A couple (Issa Rae and Kumail Nanjiani) experi...
# 26    Shallow, rich and socially successful Cher is ...
# 27    A meek Hobbit from the Shire and eight compani...
# 28    A couple travels to Sweden to visit a rural ho...
# 29    A young boy in Hitler's army finds out his mot...
# ...                                                 ...
# 1470  The true story of Captain Richard Phillips and...
# 1471  A young couple trying for a baby move into a f...
# 1472  A soon-to-be-married man's friends throw him t...
# 1473  A freak storm unleashes a species of bloodthir...
# 1474  After the death of her grandmother, Teresa com...
# 1475  A genetically inferior man assumes the identit...
# 1476  A teenager encounters romance, intrigue and a ...
# 1477  Four young friends bound by a tragic accident ...
# 1493  Anthony Hopkins, John Hurt, Anne Bancroft, Joh...
# 1494  Dev Patel, Armie Hammer, Nazanin Boniadi, Anup...
# 1495  Jane Fonda, John Phillip Law, Anita Pallenberg...
# 1496  Eddie Murphy, Judge Reinhold, John Ashton, Lis...
# 1497  Jack Nance, Charlotte Stewart, Allen Joseph, J...
# 1498  Ryan Reynolds, Samuel L. Jackson, Gary Oldman,...
# 1499  Jake Gyllenhaal, Anne Hathaway, Judy Greer, Ol...
#
#                             link
# 0      imdb.com/title/tt5727208/
# 1      imdb.com/title/tt6723592/
# 2      imdb.com/title/tt6803046/
# 3     imdb.com/title/tt10324122/
# 4      imdb.com/title/tt9619798/
# 5      imdb.com/title/tt7286456/
# 6      imdb.com/title/tt1552211/
# 7      imdb.com/title/tt8244784/
# 8     imdb.com/title/tt10886166/
# 9      imdb.com/title/tt1706620/
# 10     imdb.com/title/tt6751668/
# 11     imdb.com/title/tt1051906/
# 12     imdb.com/title/tt8946378/
# 13     imdb.com/title/tt7131622/
# 14     imdb.com/title/tt8367814/
# 15     imdb.com/title/tt4916630/
# 16     imdb.com/title/tt8936646/
# 17     imdb.com/title/tt8579674/
# 18     imdb.com/title/tt1160419/
# 19     imdb.com/title/tt4154796/
# 20     imdb.com/title/tt2066051/
# 21    imdb.com/title/tt10314450/
# 22     imdb.com/title/tt1454029/
# 23     imdb.com/title/tt3152592/
# 24     imdb.com/title/tt7798634/
# 25     imdb.com/title/tt8851668/
# 26     imdb.com/title/tt0112697/
# 27     imdb.com/title/tt0120737/
# 28     imdb.com/title/tt8772262/
# 29     imdb.com/title/tt2584384/
# ...                          ...
# 1470   imdb.com/title/tt1535109/
# 1471   imdb.com/title/tt0063522/
# 1472   imdb.com/title/tt0086927/
# 1473   imdb.com/title/tt0884328/
# 1474   imdb.com/title/tt2762506/
# 1475   imdb.com/title/tt0119177/
# 1476   imdb.com/title/tt0058371/
# 1477   imdb.com/title/tt0119345/
# 1478   imdb.com/title/tt0335345/
# 1479   imdb.com/title/tt0251736/
# 1480   imdb.com/title/tt2709768/
# 1481   imdb.com/title/tt0945513/
# 1482   imdb.com/title/tt4276820/
# 1483   imdb.com/title/tt3079380/
# 1484   imdb.com/title/tt0080120/
# 1485   imdb.com/title/tt1791528/
# 1486   imdb.com/title/tt1409024/
# 1487   imdb.com/title/tt0060429/
# 1488   imdb.com/title/tt2229499/
# 1489   imdb.com/title/tt1615160/
# 1490   imdb.com/title/tt0230600/
# 1491   imdb.com/title/tt0097441/
# 1492   imdb.com/title/tt1846589/
# 1493   imdb.com/title/tt0080678/
# 1494   imdb.com/title/tt5461944/
# 1495   imdb.com/title/tt0062711/
# 1496   imdb.com/title/tt0086960/
# 1497   imdb.com/title/tt0074486/
# 1498   imdb.com/title/tt1959563/
# 1499   imdb.com/title/tt0758752/
#
# [1500 rows x 11 columns]

# %% [markdown]
# # Save to CSV File
# to load .csv into DataFrame, use ```pd.read_csv('file_path')```.

# %%
df.to_csv('imbd_movies.csv', index=False)

# %% [markdown]
# # Useful Links

# %% [markdown]
# credit: https://github.com/Reljod/Python-Data-Scraping-IMDb-Movie-site-using-BeautifulSoup-Series-1-
#
# resource: https://www.imdb.com/search/title/?title_type=feature,tv_series&view=advanced
