# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import lxml
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm

# %% [markdown]
# # Scrape data from IMDB

# %% [markdown]
# ### By popularities

# %%
# By popularities
urls = ['https://www.imdb.com/search/title/?title_type=feature&ref_=adv_prv']

index = 51
for i in range(199): # after 10k, url style chages. Have to come up with another solution.
    urls.append('https://www.imdb.com/search/title/?title_type=feature&start=%d&ref_=adv_nxt'
                % index)
    index += 50

# %% [markdown]
# ### By genres, so classes are nearly balanced

# %%
def generate_url_by_genre(genres, num_page):
    '''
    Generates urls for scraping.
    
    Arguments:
    genres -- List of genres for scraping.
    num_page -- Number of pages to scrape for each genre.
    
    Returns:
    urls -- List of urls for scraping.
    '''
    
    urls = []
    for genre in genres:
        first_page = 'https://www.imdb.com/search/title/?title_type=feature&genres=%s&explore=title_type,genres&ref_=adv_prv'%genre
        urls.append(first_page)

        index = 51
        for i in range(num_page-1): # after 10k, url style chages. Have to come up with another solution.
            urls.append('https://www.imdb.com/search/title/?title_type=feature&genres=%s&start=%d&explore=title_type,genres&ref_=adv_nxt'
                        % (genre, index))
            index += 50
        
    print('Total of %d urls'%len(urls))
    return urls

# %%
genres = ['comedy','sci-fi','horror','romance','action','thriller','drama','mystery','crime','animation','adventure','fantasy']
urls = generate_url_by_genre(genres, num_page=199)
# Out:
# Total of 2388 urls

# %% [markdown]
# ### Scrape

# %%
movies = []

for url in tqdm(urls, position=0, leave=True):
    
    # Get data from url and parse it.
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml') # 'html' give same result
    
    # Scrape from wanted fields
    content = soup.find(id="main")
    movie_data = content.find_all("div", class_='lister-item mode-advanced')
    
    for i in range(len(movie_data)):

        # Header
        header = movie_data[i].find('h3')
        try:
            link = header.find('a').attrs['href']
            link = 'imdb.com' + link
        except:
            link = None    
        try:
            title = header.find('a').text
        except:
            title = None
        try:    
            year = header.find('span', class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','')
            try:
                year = int(year)
            except: # some has got 'II 2020'
                year = int(year.split(' ')[1])
        except:
            year = None

        # Info
        info = movie_data[i].find_all('p', class_='text-muted')[0]
        try:
            certificate = info.find('span', class_='certificate').text
        except:
            certificate = None
        try:
            runtime = int(info.find('span', class_='runtime').text.split(' ')[0])
        except:
            runtime = None
        try:
            genre = info.find('span', class_='genre').text.replace('\n','').strip()#.split(',')
        except:
            genre = None

        # Score
        score = movie_data[i].find('div', class_='ratings-bar')
        try:
            rating = float(score.find('strong').text)
        except:
            rating = None
        try:
            metascore = int(score.find('span', class_='metascore favorable').text.replace(' ',''))
        except:
            metascore = None

        # Story
        try:
            story = movie_data[i].find_all('p', class_='text-muted')[1].text.replace('\n','').strip()
        except:
            story = None

        # People
        people = movie_data[i].find('p', class_='').text

        if '|' in people: # movies
            try:
                director = people.split('|')[0].replace('\n','').strip().replace('Directors:','').replace('Director:','')
                #director = [name.strip() for name in director.split(',')]
            except:
                director = None
            try:
                cast = people.split('|')[1].replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        else: # series
            director = None
            try:
                cast = people.replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        # Store each in a dict
        movie_dict = {}
        movie_dict['link'] = link
        movie_dict['title'] = title
        movie_dict['year'] = year
        movie_dict['certificate'] = certificate
        movie_dict['runtime'] = runtime
        movie_dict['genre'] = genre
        movie_dict['rating'] = rating
        movie_dict['metascore'] = metascore
        movie_dict['story'] = story
        movie_dict['director'] = director
        movie_dict['cast'] = cast

        # Append the dict to a list
        movies.append(movie_dict)
# Out:
# 100%|██████████| 2388/2388 [2:00:06<00:00,  3.96s/it]

# %% [markdown]
# # Convert to DataFrame
# DataFrame converts ```year```, ```runtime```, and ```metascore``` which were ```int``` to ```float```. Further processings, include ```.dropna()``` and ```.astype()```, are required to convert them back.

# %%
# Convert to DataFrame and rearrange columns order
df = pd.DataFrame(movies, columns=['title','year','certificate','runtime','genre','rating','metascore','story','director','cast','link'])
df
# Out:
#                                                     title    year certificate  \
# 0                               The King of Staten Island  2020.0           R
# 1                                              Knives Out  2019.0          15
# 2                                            Palm Springs  2020.0        None
# 3                                            Gisaengchung  2019.0          15
# 4                        Once Upon a Time... in Hollywood  2019.0          18
# 5                                           The Gentlemen  2019.0          15
# 6                               Bill & Ted Face the Music  2020.0        None
# 7                                           Gulabo Sitabo  2020.0        None
# 8               The Personal History of David Copperfield  2019.0          PG
# 9         Eurovision Song Contest: The Story of Fire Saga  2020.0       PG-13
# 10                                        The Wrong Missy  2020.0        None
# 11                                             Chhichhore  2019.0        None
# 12                                               Clueless  1995.0       PG-13
# 13                                            Jojo Rabbit  2019.0       PG-13
# 14                                           Ready or Not  2019.0          18
# 15                                          Feel the Beat  2020.0        None
# 16                                      Bad Boys for Life  2020.0           R
# 17                                     Back to the Future  1985.0        None
# 18                                              Lady Bird  2017.0          15
# 19                                              Babyteeth  2019.0        None
# 20                                Jumanji: The Next Level  2019.0       PG-13
# 21                                                 Scoob!  2020.0          PG
# 22                                                  Emma.  2020.0          PG
# 23                                                 Onward  2020.0          PG
# 24                                     Sonic the Hedgehog  2020.0           G
# 25                                    The Disaster Artist  2017.0           R
# 26                                     Do the Right Thing  1989.0        None
# 27                                            Guns Akimbo  2019.0           R
# 28                                               Dolittle  2020.0          PG
# 29                                          Almost Famous  2000.0           R
# ...                                                   ...     ...         ...
# 116064                          Jade Duboir's Dirty Deeds  2001.0        None
# 116065                                Daughter of Sindbad  1958.0        None
# 116066                                       Play with Me     NaN        None
# 116067                                  Kidlat... ngayon!  1953.0        None
# 116068                                   Once Upon a Time  1971.0        None
# 116069                                    Legend of Nezha     NaN        None
# 116070  The Further Adventures of Anse and Bhule in No...  2017.0        None
# 116071                                           Jarilike  2016.0        None
# 116072                                    Meridian Factor     NaN        None
# 116073                                   Cross-Eyed Waltz  2005.0        None
# 116074                                      Dhanna Bhagat  1945.0        None
# 116075                                           Parallex     NaN        None
# 116076                          Der lange Ritt zur Schule  1982.0        None
# 116077                 Snow White and the Prince of Frogs  1996.0        None
# 116078                                       White Demise  2020.0        None
# 116079                                            Lucerna  1938.0        None
# 116080                                                 63     NaN        None
# 116081                                    Nuechidein bang  2018.0        None
# 116082                                         Kid Normal  2017.0        None
# 116083                                          Sentience  2015.0        None
# 116084                             A szalmabábuk lázadása  2001.0        None
# 116085                                        Vs. Reality     NaN        None
# 116086                          Bihar Ke Darshaniya Sthan  1955.0        None
# 116087                           Historias del desencanto  2005.0        None
# 116088                                            Cecilia  2012.0        None
# 116089               The Rescuers and the Catcher's Curse     NaN        None
# 116090                Squatch! Curse of the Tree Guardian  2012.0        None
# 116091                                 Taste of Centuries  2003.0        None
# 116092                    If Only We Knew How We Got Here     NaN        None
# 116093                                            Tig Hug  2017.0        None
#
#         runtime                         genre  rating  metascore  \
# 0         136.0                 Comedy, Drama     7.2       68.0
# 1         130.0          Comedy, Crime, Drama     7.9       82.0
# 2          90.0               Comedy, Romance     7.2       83.0
# 3         132.0       Comedy, Drama, Thriller     8.6       96.0
# 4         161.0                 Comedy, Drama     7.7       83.0
# 5         113.0         Action, Comedy, Crime     7.9        NaN
# 6           NaN         Comedy, Music, Sci-Fi     NaN        NaN
# 7         124.0                 Comedy, Drama     6.5        NaN
# 8         119.0                 Comedy, Drama     6.3       75.0
# 9         123.0                 Comedy, Music     6.7        NaN
# 10         90.0               Comedy, Romance     5.7        NaN
# 11        143.0                 Comedy, Drama     8.1        NaN
# 12         97.0               Comedy, Romance     6.8       68.0
# 13        108.0            Comedy, Drama, War     7.9        NaN
# 14         95.0       Comedy, Horror, Mystery     6.8       64.0
# 15        109.0         Comedy, Drama, Family     6.4        NaN
# 16        124.0         Action, Comedy, Crime     6.7        NaN
# 17        116.0     Adventure, Comedy, Sci-Fi     8.5       87.0
# 18         94.0                 Comedy, Drama     7.4       94.0
# 19        118.0                 Comedy, Drama     6.9       76.0
# 20        123.0     Action, Adventure, Comedy     6.7        NaN
# 21         93.0  Animation, Adventure, Comedy     5.7        NaN
# 22        124.0                 Comedy, Drama     6.8       71.0
# 23        102.0  Animation, Adventure, Comedy     7.5       61.0
# 24         99.0     Action, Adventure, Comedy     6.6        NaN
# 25        104.0      Biography, Comedy, Drama     7.4       76.0
# 26        120.0                 Comedy, Drama     7.9       93.0
# 27         98.0                Action, Comedy     6.3        NaN
# 28        101.0     Adventure, Comedy, Family     5.6        NaN
# 29        122.0      Adventure, Comedy, Drama     7.9       90.0
# ...         ...                           ...     ...        ...
# 116064      NaN                       Fantasy     NaN        NaN
# 116065      NaN                       Fantasy     NaN        NaN
# 116066      NaN               Fantasy, Horror     NaN        NaN
# 116067      NaN               Action, Fantasy     NaN        NaN
# 116068      NaN              Fantasy, Romance     NaN        NaN
# 116069      NaN                       Fantasy     NaN        NaN
# 116070    105.0     Adventure, Drama, Fantasy     7.2        NaN
# 116071    128.0                       Fantasy     8.7        NaN
# 116072      NaN    Action, Adventure, Fantasy     NaN        NaN
# 116073     71.0    Adventure, Comedy, Fantasy     6.8        NaN
# 116074      NaN                       Fantasy     NaN        NaN
# 116075      NaN       Action, Fantasy, Sci-Fi     NaN        NaN
# 116076     84.0       Comedy, Family, Fantasy     6.2        NaN
# 116077     80.0            Animation, Fantasy     NaN        NaN
# 116078      NaN                Drama, Fantasy     NaN        NaN
# 116079      NaN                       Fantasy     6.5        NaN
# 116080      NaN                       Fantasy     NaN        NaN
# 116081    130.0                Drama, Fantasy     5.8        NaN
# 116082      NaN        Comedy, Drama, Fantasy     NaN        NaN
# 116083     92.0       Fantasy, Horror, Sci-Fi     NaN        NaN
# 116084     83.0      Drama, Family, Animation     6.1        NaN
# 116085      NaN       Action, Fantasy, Sci-Fi     NaN        NaN
# 116086      NaN                       Fantasy     NaN        NaN
# 116087    120.0        Comedy, Drama, Fantasy     7.2        NaN
# 116088     66.0                Drama, Fantasy     NaN        NaN
# 116089      NaN                       Fantasy     NaN        NaN
# 116090      NaN     Fantasy, Horror, Thriller     4.1        NaN
# 116091     93.0               Fantasy, Horror     NaN        NaN
# 116092      NaN                       Fantasy     NaN        NaN
# 116093    100.0        Drama, Family, Fantasy     NaN        NaN
#
#                                                     story  \
# 0       Scott has been a case of arrested development ...
# 1       A detective investigates the death of a patria...
# 2       When carefree Nyles and reluctant maid of hono...
# 3       Greed and class discrimination threaten the ne...
# 4       A faded television actor and his stunt double ...
# 5       An American expat tries to sell off his highly...
# 6       Once told they'd save the universe during a ti...
# 7       Two scheming men get caught up in a game of on...
# 8       A modern take on Charles Dickens's classic tal...
# 9       When aspiring musicians Lars and Sigrit are gi...
# 10      Tim thinks he's invited the woman of his dream...
# 11      A tragic incident forces Anirudh, a middle-age...
# 12      Shallow, rich and socially successful Cher is ...
# 13      A young boy in Hitler's army finds out his mot...
# 14      A bride's wedding night takes a sinister turn ...
# 15      After failing to find success on Broadway, Apr...
# 16      Miami detectives Mike Lowrey and Marcus Burnet...
# 17      Marty McFly, a 17-year-old high school student...
# 18      In 2002, an artistically inclined seventeen-ye...
# 19      Milla, a seriously ill teenager falls in love ...
# 20      In Jumanji: The Next Level, the gang is back b...
# 21      Scooby and the gang face their most challengin...
# 22      In 1800s England, a well meaning but selfish y...
# 23      Two elven brothers embark on a quest to bring ...
# 24      After discovering a small, blue, fast hedgehog...
# 25      When Greg Sestero, an aspiring film actor, mee...
# 26      On the hottest day of the year on a street in ...
# 27      A guy relies on his newly-acquired gladiator s...
# 28      A physician who can talk to animals embarks on...
# 29      A high-school boy is given the chance to write...
# ...                                                   ...
# 116064  Jade Duboir lives out her fantasies in an erot...
# 116065                                         Add a Plot
# 116066                                         Add a Plot
# 116067         Pinoy version of America's Captain Marvel.
# 116068                                         Add a Plot
# 116069  The Legend of Nezha is based on the Chinese my...
# 116070  The Further Adventures of Anse and Bhule is a ...
# 116071  It is the beginning of the 9th century in sout...
# 116072  Plot kept under wraps. Described as a sci-fi f...
# 116073  The Mayor of a surreal suburban town and a gro...
# 116074                                         Add a Plot
# 116075                                         Add a Plot
# 116076  A young boy fantasizes his way to school into ...
# 116077                                         Add a Plot
# 116078  A desperate woman embarks on a journey to find...
# 116079                                         Add a Plot
# 116080  A sixty-three year old high school substitute ...
# 116081  'Let me be your witness. I will witness every ...
# 116082                                         Add a Plot
# 116083  A deadly computer virus is spreading from mach...
# 116084  After the Hungarian War of Independence was lo...
# 116085  If your deepest desires spontaneously manifest...
# 116086                                         Add a Plot
# 116087  Alejandro Valle's "Stories of Disenchatment" i...
# 116088  In Raquel Sigüenza, a small town of strong soc...
# 18       imdb.com/title/tt4925292/
# 19       imdb.com/title/tt8399664/
# 20       imdb.com/title/tt7975244/
# 21       imdb.com/title/tt3152592/
# 22       imdb.com/title/tt9214832/
# 23       imdb.com/title/tt7146812/
# 24       imdb.com/title/tt3794354/
# 25       imdb.com/title/tt3521126/
# 26       imdb.com/title/tt0097216/
# 27       imdb.com/title/tt6902676/
# 28       imdb.com/title/tt6673612/
# 29       imdb.com/title/tt0181875/
# ...                            ...
# 116064   imdb.com/title/tt1989540/
# 116065   imdb.com/title/tt2145675/
# 116066   imdb.com/title/tt9683200/
# 116067   imdb.com/title/tt0764802/
# 116068   imdb.com/title/tt2020070/
# 116069   imdb.com/title/tt5651150/
# 116070   imdb.com/title/tt2596158/
# 116071   imdb.com/title/tt4043906/
# 116072   imdb.com/title/tt9892896/
# 116073   imdb.com/title/tt0430957/
# 116074   imdb.com/title/tt0140957/
# 116075   imdb.com/title/tt6044166/
# 116076   imdb.com/title/tt0084232/
# 116077  imdb.com/title/tt12351802/
# 116078  imdb.com/title/tt12137660/
# 116079   imdb.com/title/tt0151405/
# 116080   imdb.com/title/tt6040336/
# 116081   imdb.com/title/tt5896860/
# 116082  imdb.com/title/tt12161946/
# 116083   imdb.com/title/tt3476700/
# 116084   imdb.com/title/tt0274919/
# 116085   imdb.com/title/tt2301269/
# 116086   imdb.com/title/tt0214541/
# 116087   imdb.com/title/tt0451759/
# 116088   imdb.com/title/tt2433224/
# 116089   imdb.com/title/tt3313380/
# 116090   imdb.com/title/tt2413816/
# 116091  imdb.com/title/tt11366772/
# 116092   imdb.com/title/tt7232384/
# 116093   imdb.com/title/tt2919222/
#
# [116094 rows x 11 columns]

# %% [markdown]
# Remove duplicated rows using ```.drop_duplicates()```

# %%
df.drop_duplicates(subset=['title'], inplace=True)

# %%
df
# Out:
#                                                     title    year certificate  \
# 0                               The King of Staten Island  2020.0           R
# 1                                              Knives Out  2019.0          15
# 2                                            Palm Springs  2020.0        None
# 3                                            Gisaengchung  2019.0          15
# 4                        Once Upon a Time... in Hollywood  2019.0          18
# 5                                           The Gentlemen  2019.0          15
# 6                               Bill & Ted Face the Music  2020.0        None
# 7                                           Gulabo Sitabo  2020.0        None
# 8               The Personal History of David Copperfield  2019.0          PG
# 9         Eurovision Song Contest: The Story of Fire Saga  2020.0       PG-13
# 10                                        The Wrong Missy  2020.0        None
# 11                                             Chhichhore  2019.0        None
# 12                                               Clueless  1995.0       PG-13
# 13                                            Jojo Rabbit  2019.0       PG-13
# 14                                           Ready or Not  2019.0          18
# 15                                          Feel the Beat  2020.0        None
# 16                                      Bad Boys for Life  2020.0           R
# 17                                     Back to the Future  1985.0        None
# 18                                              Lady Bird  2017.0          15
# 19                                              Babyteeth  2019.0        None
# 20                                Jumanji: The Next Level  2019.0       PG-13
# 21                                                 Scoob!  2020.0          PG
# 22                                                  Emma.  2020.0          PG
# 23                                                 Onward  2020.0          PG
# 24                                     Sonic the Hedgehog  2020.0           G
# 25                                    The Disaster Artist  2017.0           R
# 26                                     Do the Right Thing  1989.0        None
# 27                                            Guns Akimbo  2019.0           R
# 28                                               Dolittle  2020.0          PG
# 29                                          Almost Famous  2000.0           R
# ...                                                   ...     ...         ...
# 116057                                 Skazanie o Rustame  1971.0        None
# 116058                                        Hind Kesari  1935.0        None
# 116059                                The Inn at the Mist     NaN        None
# 116060                                 Sins of the Dragon  2012.0        None
# 116061                                Reacciones adversas  2011.0        None
# 116062                                 Cagin of Chrysaint  2010.0        None
# 116063                                    La raíz del mal  2008.0        None
# 116064                          Jade Duboir's Dirty Deeds  2001.0        None
# 116065                                Daughter of Sindbad  1958.0        None
# 116066                                       Play with Me     NaN        None
# 116067                                  Kidlat... ngayon!  1953.0        None
# 116069                                    Legend of Nezha     NaN        None
# 116070  The Further Adventures of Anse and Bhule in No...  2017.0        None
# 116071                                           Jarilike  2016.0        None
# 116073                                   Cross-Eyed Waltz  2005.0        None
# 116074                                      Dhanna Bhagat  1945.0        None
# 116076                          Der lange Ritt zur Schule  1982.0        None
# 116078                                       White Demise  2020.0        None
# 116079                                            Lucerna  1938.0        None
# 116080                                                 63     NaN        None
# 116081                                    Nuechidein bang  2018.0        None
# 116082                                         Kid Normal  2017.0        None
# 116086                          Bihar Ke Darshaniya Sthan  1955.0        None
# 116087                           Historias del desencanto  2005.0        None
# 116088                                            Cecilia  2012.0        None
# 116089               The Rescuers and the Catcher's Curse     NaN        None
# 116090                Squatch! Curse of the Tree Guardian  2012.0        None
# 116091                                 Taste of Centuries  2003.0        None
# 116092                    If Only We Knew How We Got Here     NaN        None
# 116093                                            Tig Hug  2017.0        None
#
#         runtime                         genre  rating  metascore  \
# 0         136.0                 Comedy, Drama     7.2       68.0
# 1         130.0          Comedy, Crime, Drama     7.9       82.0
# 2          90.0               Comedy, Romance     7.2       83.0
# 3         132.0       Comedy, Drama, Thriller     8.6       96.0
# 4         161.0                 Comedy, Drama     7.7       83.0
# 5         113.0         Action, Comedy, Crime     7.9        NaN
# 6           NaN         Comedy, Music, Sci-Fi     NaN        NaN
# 7         124.0                 Comedy, Drama     6.5        NaN
# 8         119.0                 Comedy, Drama     6.3       75.0
# 9         123.0                 Comedy, Music     6.7        NaN
# 10         90.0               Comedy, Romance     5.7        NaN
# 11        143.0                 Comedy, Drama     8.1        NaN
# 12         97.0               Comedy, Romance     6.8       68.0
# 13        108.0            Comedy, Drama, War     7.9        NaN
# 14         95.0       Comedy, Horror, Mystery     6.8       64.0
# 15        109.0         Comedy, Drama, Family     6.4        NaN
# 16        124.0         Action, Comedy, Crime     6.7        NaN
# 17        116.0     Adventure, Comedy, Sci-Fi     8.5       87.0
# 18         94.0                 Comedy, Drama     7.4       94.0
# 19        118.0                 Comedy, Drama     6.9       76.0
# 20        123.0     Action, Adventure, Comedy     6.7        NaN
# 21         93.0  Animation, Adventure, Comedy     5.7        NaN
# 22        124.0                 Comedy, Drama     6.8       71.0
# 23        102.0  Animation, Adventure, Comedy     7.5       61.0
# 24         99.0     Action, Adventure, Comedy     6.6        NaN
# 25        104.0      Biography, Comedy, Drama     7.4       76.0
# 26        120.0                 Comedy, Drama     7.9       93.0
# 27         98.0                Action, Comedy     6.3        NaN
# 28        101.0     Adventure, Comedy, Family     5.6        NaN
# 29        122.0      Adventure, Comedy, Drama     7.9       90.0
# ...         ...                           ...     ...        ...
# 116057    147.0     Adventure, Drama, Fantasy     7.3        NaN
# 116058    141.0            Adventure, Fantasy     NaN        NaN
# 116059      NaN               Fantasy, Horror     NaN        NaN
# 116060     60.0               Action, Fantasy     7.2        NaN
# 116061     74.0        Action, Drama, Fantasy     6.6        NaN
# 116062     81.0     Fantasy, History, Romance     NaN        NaN
# 116063     80.0               Fantasy, Horror     4.7        NaN
# 116064      NaN                       Fantasy     NaN        NaN
# 116065      NaN                       Fantasy     NaN        NaN
# 116066      NaN               Fantasy, Horror     NaN        NaN
# 116067      NaN               Action, Fantasy     NaN        NaN
# 116069      NaN                       Fantasy     NaN        NaN
# 116070    105.0     Adventure, Drama, Fantasy     7.2        NaN
# 116071    128.0                       Fantasy     8.7        NaN
# 116073     71.0    Adventure, Comedy, Fantasy     6.8        NaN
# 116074      NaN                       Fantasy     NaN        NaN
# 116076     84.0       Comedy, Family, Fantasy     6.2        NaN
# 116078      NaN                Drama, Fantasy     NaN        NaN
# 116079      NaN                       Fantasy     6.5        NaN
# 116080      NaN                       Fantasy     NaN        NaN
# 116081    130.0                Drama, Fantasy     5.8        NaN
# 116082      NaN        Comedy, Drama, Fantasy     NaN        NaN
# 116086      NaN                       Fantasy     NaN        NaN
# 116087    120.0        Comedy, Drama, Fantasy     7.2        NaN
# 116088     66.0                Drama, Fantasy     NaN        NaN
# 116089      NaN                       Fantasy     NaN        NaN
# 116090      NaN     Fantasy, Horror, Thriller     4.1        NaN
# 116091     93.0               Fantasy, Horror     NaN        NaN
# 116092      NaN                       Fantasy     NaN        NaN
# 116093    100.0        Drama, Family, Fantasy     NaN        NaN
#
#                                                     story  \
# 0       Scott has been a case of arrested development ...
# 1       A detective investigates the death of a patria...
# 2       When carefree Nyles and reluctant maid of hono...
# 3       Greed and class discrimination threaten the ne...
# 4       A faded television actor and his stunt double ...
# 5       An American expat tries to sell off his highly...
# 6       Once told they'd save the universe during a ti...
# 7       Two scheming men get caught up in a game of on...
# 8       A modern take on Charles Dickens's classic tal...
# 9       When aspiring musicians Lars and Sigrit are gi...
# 10      Tim thinks he's invited the woman of his dream...
# 11      A tragic incident forces Anirudh, a middle-age...
# 12      Shallow, rich and socially successful Cher is ...
# 13      A young boy in Hitler's army finds out his mot...
# 14      A bride's wedding night takes a sinister turn ...
# 15      After failing to find success on Broadway, Apr...
# 16      Miami detectives Mike Lowrey and Marcus Burnet...
# 17      Marty McFly, a 17-year-old high school student...
# 18      In 2002, an artistically inclined seventeen-ye...
# 19      Milla, a seriously ill teenager falls in love ...
# 20      In Jumanji: The Next Level, the gang is back b...
# 21      Scooby and the gang face their most challengin...
# 22      In 1800s England, a well meaning but selfish y...
# 23      Two elven brothers embark on a quest to bring ...
# 24      After discovering a small, blue, fast hedgehog...
# 25      When Greg Sestero, an aspiring film actor, mee...
# 26      On the hottest day of the year on a street in ...
# 27      A guy relies on his newly-acquired gladiator s...
# 28      A physician who can talk to animals embarks on...
# 29      A high-school boy is given the chance to write...
# ...                                                   ...
# 116057                                         Add a Plot
# 116058  A Ruritanian drama mainly featuring the stunts...
# 116059  On October 31st, 1870 on the coast of England ...
# 116088  Sergio Arévalo, Juan Pablo Coronel, Ernesto Ma...
# 116089
# 116090  Felix Alonzo, B.K-McKee, Holli Breedlove, Jose...
# 116091  Calliope Georgousi, Thomas Kastias, Efi Katsaf...
# 116092  Tim Spriggs, Luisa Guerreiro, Diezel Ramos, Ta...
# 116093  Takahiro Hirano, Takamitsu Nonaka, Ryo Ono, Ta...
#
#                               link
# 0        imdb.com/title/tt9686708/
# 1        imdb.com/title/tt8946378/
# 2        imdb.com/title/tt9484998/
# 3        imdb.com/title/tt6751668/
# 4        imdb.com/title/tt7131622/
# 5        imdb.com/title/tt8367814/
# 6        imdb.com/title/tt1086064/
# 7       imdb.com/title/tt10333912/
# 8        imdb.com/title/tt6439020/
# 9        imdb.com/title/tt8580274/
# 10       imdb.com/title/tt9619798/
# 11       imdb.com/title/tt9052870/
# 12       imdb.com/title/tt0112697/
# 13       imdb.com/title/tt2584384/
# 14       imdb.com/title/tt7798634/
# 15      imdb.com/title/tt10714856/
# 16       imdb.com/title/tt1502397/
# 17       imdb.com/title/tt0088763/
# 18       imdb.com/title/tt4925292/
# 19       imdb.com/title/tt8399664/
# 20       imdb.com/title/tt7975244/
# 21       imdb.com/title/tt3152592/
# 22       imdb.com/title/tt9214832/
# 23       imdb.com/title/tt7146812/
# 24       imdb.com/title/tt3794354/
# 25       imdb.com/title/tt3521126/
# 26       imdb.com/title/tt0097216/
# 27       imdb.com/title/tt6902676/
# 28       imdb.com/title/tt6673612/
# 29       imdb.com/title/tt0181875/
# ...                            ...
# 116057   imdb.com/title/tt2262101/
# 116058   imdb.com/title/tt0268360/
# 116059   imdb.com/title/tt4046300/
# 116060   imdb.com/title/tt2335554/
# 116061   imdb.com/title/tt1766027/
# 116062   imdb.com/title/tt1729527/
# 116063   imdb.com/title/tt2205539/
# 116064   imdb.com/title/tt1989540/
# 116065   imdb.com/title/tt2145675/
# 116066   imdb.com/title/tt9683200/
# 116067   imdb.com/title/tt0764802/
# 116069   imdb.com/title/tt5651150/
# 116070   imdb.com/title/tt2596158/
# 116071   imdb.com/title/tt4043906/
# 116073   imdb.com/title/tt0430957/
# 116074   imdb.com/title/tt0140957/
# 116076   imdb.com/title/tt0084232/
# 116078  imdb.com/title/tt12137660/
# 116079   imdb.com/title/tt0151405/
# 116080   imdb.com/title/tt6040336/
# 116081   imdb.com/title/tt5896860/
# 116082  imdb.com/title/tt12161946/
# 116086   imdb.com/title/tt0214541/
# 116087   imdb.com/title/tt0451759/
# 116088   imdb.com/title/tt2433224/
# 116089   imdb.com/title/tt3313380/
# 116090   imdb.com/title/tt2413816/
# 116091  imdb.com/title/tt11366772/
# 116092   imdb.com/title/tt7232384/
# 116093   imdb.com/title/tt2919222/
#
# [64180 rows x 11 columns]

# %% [markdown]
# # Save to CSV File
# to load .csv into DataFrame, use ```pd.read_csv('file_path')```.

# %%
df.to_csv('imbd_movies_by_genre.csv', index=False)

# %% [markdown]
# # Useful Links

# %% [markdown]
# credit: https://github.com/Reljod/Python-Data-Scraping-IMDb-Movie-site-using-BeautifulSoup-Series-1-
#
# resource: https://www.imdb.com/search/title/?title_type=feature,tv_series&view=advanced
