# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import lxml
from bs4 import BeautifulSoup
from requests import get
from tqdm import tqdm

# %% [markdown]
# # Scrape data from IMDB

# %%
urls = ['https://www.imdb.com/search/title/?title_type=feature&ref_=adv_prv']

index = 51
for i in range(199): # after 10k, url style chages. Have to come up with another solution.
    urls.append('https://www.imdb.com/search/title/?title_type=feature&start=%d&ref_=adv_nxt'
                % index)
    index += 50

# %%
movies = []

for url in tqdm(urls, position=0, leave=True):
    
    # Get data from url and parse it.
    page = get(url)
    soup = BeautifulSoup(page.content, 'lxml') # 'html' give same result
    
    # Scrape from wanted fields
    content = soup.find(id="main")
    movie_data = content.find_all("div", class_='lister-item mode-advanced')
    
    for i in range(len(movie_data)):

        # Header
        header = movie_data[i].find('h3')
        try:
            link = header.find('a').attrs['href']
            link = 'imdb.com' + link
        except:
            link = None    
        try:
            title = header.find('a').text
        except:
            title = None
        try:    
            year = header.find('span', class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','')
            try:
                year = int(year)
            except: # some has got 'II 2020'
                year = int(year.split(' ')[1])
        except:
            year = None

        # Info
        info = movie_data[i].find_all('p', class_='text-muted')[0]
        try:
            certificate = info.find('span', class_='certificate').text
        except:
            certificate = None
        try:
            runtime = int(info.find('span', class_='runtime').text.split(' ')[0])
        except:
            runtime = None
        try:
            genre = info.find('span', class_='genre').text.replace('\n','').strip()#.split(',')
        except:
            genre = None

        # Score
        score = movie_data[i].find('div', class_='ratings-bar')
        try:
            rating = float(score.find('strong').text)
        except:
            rating = None
        try:
            metascore = int(score.find('span', class_='metascore favorable').text.replace(' ',''))
        except:
            metascore = None

        # Story
        try:
            story = movie_data[i].find_all('p', class_='text-muted')[1].text.replace('\n','').strip()
        except:
            story = None

        # People
        people = movie_data[i].find('p', class_='').text

        if '|' in people: # movies
            try:
                director = people.split('|')[0].replace('\n','').strip().replace('Directors:','').replace('Director:','')
                #director = [name.strip() for name in director.split(',')]
            except:
                director = None
            try:
                cast = people.split('|')[1].replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        else: # series
            director = None
            try:
                cast = people.replace('\n','').strip().replace('Stars:','')
                #cast = [name.strip() for name in cast.split(',')]
            except:
                cast = None

        # Store each in a dict
        movie_dict = {}
        movie_dict['link'] = link
        movie_dict['title'] = title
        movie_dict['year'] = year
        movie_dict['certificate'] = certificate
        movie_dict['runtime'] = runtime
        movie_dict['genre'] = genre
        movie_dict['rating'] = rating
        movie_dict['metascore'] = metascore
        movie_dict['story'] = story
        movie_dict['director'] = director
        movie_dict['cast'] = cast

        # Append the dict to a list
        movies.append(movie_dict)
# Out:
# 100%|██████████| 200/200 [07:41<00:00,  2.52s/it]

# %% [markdown]
# # Convert to DataFrame
# DataFrame converts ```year```, ```runtime```, and ```metascore``` which were ```int``` to ```float```. Further processings, include ```.dropna()``` and ```.astype()```, are required to convert them back.

# %%
# 0       114.0              Drama, Romance     3.5        NaN
# 1       154.0       Adventure, Drama, War     6.7       82.0
# 2        95.0  Adventure, Family, Fantasy     4.1        NaN
# 3       136.0               Comedy, Drama     7.2       68.0
# 4       130.0        Comedy, Crime, Drama     7.9       82.0
# 5        93.0      Drama, Horror, Mystery     5.3        NaN
# 6        90.0             Comedy, Romance     7.2       83.0
# 7         NaN    Action, Sci-Fi, Thriller     NaN        NaN
# 8       135.0      Crime, Drama, Thriller     7.5       90.0
# 9       132.0     Comedy, Drama, Thriller     8.6       96.0
# 10      148.0     Action, Crime, Thriller     3.6        NaN
# 11      161.0               Comedy, Drama     7.7       83.0
# 12       90.0    Action, Horror, Thriller     6.4        NaN
# 13      122.0      Crime, Drama, Thriller     8.5        NaN
# 14      113.0       Action, Comedy, Crime     7.9        NaN
# 15      137.0     Biography, Crime, Drama     7.6       68.0
# 16        NaN    Adventure, Drama, Sci-Fi     NaN        NaN
# 17       93.0             Drama, Thriller     6.2        NaN
# 18        NaN       Comedy, Music, Sci-Fi     NaN        NaN
# 19      124.0               Comedy, Drama     6.5        NaN
# 20      181.0    Action, Adventure, Drama     8.4       78.0
# 21      119.0               Comedy, Drama     6.3       75.0
# 22      124.0     Horror, Mystery, Sci-Fi     7.1       72.0
# 23      119.0                  Drama, War     8.3       78.0
# 24       91.0      Drama, Mystery, Sci-Fi     6.7       84.0
# 25      100.0                       Crime     3.7        NaN
# 26      126.0       Action, Drama, Sci-Fi     7.1       84.0
# 27      123.0   Adventure, Drama, Mystery     6.6       80.0
# 28      148.0      Drama, Horror, Mystery     7.1       72.0
# 29      123.0               Comedy, Music     NaN        NaN
# ...       ...                         ...     ...        ...
# 9970    102.0             Comedy, Romance     5.0        NaN
# 9971     98.0                      Horror     6.5        NaN
# 9972     79.0      Drama, Fantasy, Horror     4.7       62.0
# 9973     90.0                     Romance     5.7        NaN
# 9974    123.0              Drama, Romance     6.3        NaN
# 9975    117.0               Comedy, Drama     7.5        NaN
# 9976    112.0               Comedy, Drama     6.5        NaN
# 9977      NaN                      Action     NaN        NaN
# 9978    103.0                       Drama     7.5        NaN
# 9979    101.0       Comedy, Drama, Family     5.4        NaN
# 9980     96.0   Comedy, Romance, Thriller     5.8        NaN
# 9981    105.0           Action, Adventure     5.2        NaN
# 9982    115.0            Biography, Drama     6.9        NaN
# 9983     90.0              Drama, Romance     6.7       63.0
# 9984    106.0                       Drama     6.3        NaN
# 9985     91.0               Comedy, Drama     6.4       70.0
# 9986    119.0             Drama, Thriller     6.7        NaN
# 9987     93.0    Action, Adventure, Crime     4.8        NaN
# 9988    105.0      Comedy, Drama, Romance     7.1        NaN
# 9989     98.0              Drama, Romance     7.1       63.0
# 9990     99.0      Action, Comedy, Horror     5.5        NaN
# 9991    131.0       Biography, Drama, War     7.2        NaN
# 9992     94.0                      Action     5.4        NaN
# 9993     99.0              Comedy, Family     5.4        NaN
# 9998   Mark Tandy, Russell Balogh, Andrew Havill, Heinz
# 9999  Csaba Czene, Gergely Trócsányi, Marc Bischoff,...
#
#                             link
# 0     imdb.com/title/tt10886166/
# 1      imdb.com/title/tt9777644/
# 2      imdb.com/title/tt3089630/
# 3      imdb.com/title/tt9686708/
# 4      imdb.com/title/tt8946378/
# 5      imdb.com/title/tt8201852/
# 6      imdb.com/title/tt9484998/
# 7      imdb.com/title/tt6723592/
# 8      imdb.com/title/tt5727208/
# 9      imdb.com/title/tt6751668/
# 10     imdb.com/title/tt1552211/
# 11     imdb.com/title/tt7131622/
# 12     imdb.com/title/tt8244784/
# 13     imdb.com/title/tt7286456/
# 14     imdb.com/title/tt8367814/
# 15     imdb.com/title/tt4916630/
# 16     imdb.com/title/tt1160419/
# 17     imdb.com/title/tt6436726/
# 18     imdb.com/title/tt1086064/
# 19    imdb.com/title/tt10333912/
# 20     imdb.com/title/tt4154796/
# 21     imdb.com/title/tt6439020/
# 22     imdb.com/title/tt1051906/
# 23     imdb.com/title/tt8579674/
# 24     imdb.com/title/tt6803046/
# 25     imdb.com/title/tt7703924/
# 26     imdb.com/title/tt1706620/
# 27     imdb.com/title/tt2935510/
# 28     imdb.com/title/tt8772262/
# 29     imdb.com/title/tt8580274/
# ...                          ...
# 9970   imdb.com/title/tt0086352/
# 9971   imdb.com/title/tt8656686/
# 9972   imdb.com/title/tt4682708/
# 9973   imdb.com/title/tt9168992/
# 9974   imdb.com/title/tt3729920/
# 9975   imdb.com/title/tt0100519/
# 9976   imdb.com/title/tt0475984/
# 9977   imdb.com/title/tt7031324/
# 9978   imdb.com/title/tt0069393/
# 9979   imdb.com/title/tt0141109/
# 9980   imdb.com/title/tt0104438/
# 9981   imdb.com/title/tt0098180/
# 9982   imdb.com/title/tt4459156/
# 9983   imdb.com/title/tt0063803/
# 9984   imdb.com/title/tt1032819/
# 9985   imdb.com/title/tt6173484/
# 9986   imdb.com/title/tt0118531/
# 9987   imdb.com/title/tt0772193/
# 9988   imdb.com/title/tt0497137/
# 9989   imdb.com/title/tt1625150/
# 9990   imdb.com/title/tt7453418/
# 9991   imdb.com/title/tt4969044/
# 9992   imdb.com/title/tt9535950/
# 9993   imdb.com/title/tt0388419/
# 9994   imdb.com/title/tt0068156/
# 9995   imdb.com/title/tt4305148/
# 9996   imdb.com/title/tt9648886/
# 9997   imdb.com/title/tt0381392/
# 9998   imdb.com/title/tt4104054/
# 9999   imdb.com/title/tt0410730/
#
# [10000 rows x 11 columns]

# %% [markdown]
# # Save to CSV File
# to load .csv into DataFrame, use ```pd.read_csv('file_path')```.

# %%
df.to_csv('imbd_movies.csv', index=False)

# %% [markdown]
# # Useful Links

# %% [markdown]
# credit: https://github.com/Reljod/Python-Data-Scraping-IMDb-Movie-site-using-BeautifulSoup-Series-1-
#
# resource: https://www.imdb.com/search/title/?title_type=feature,tv_series&view=advanced
